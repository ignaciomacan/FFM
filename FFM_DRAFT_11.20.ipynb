# %% [markdown]
# <h1 style="
#     font-family: Garamond;
#     font-size: 34px;
#     color: #2774AE;
#     font-weight: 700;
#     text-shadow:
#         -1px -1px 0 #000,
#          1px -1px 0 #000,
#         -1px  1px 0 #000,
#          1px  1px 0 #000;
# ">
# Replication Report on <em>"A Five-Factor Asset Pricing Model"</em> (Fama & French, 2015)
# </h1>
#
# <h2 style="
#     font-family: Garamond;
#     font-size: 22px;
#     color: #FFD100;
#     font-style: italic;
#     text-shadow:
#         -1px -1px 0 #000,
#          1px -1px 0 #000,
#         -1px  1px 0 #000,
#          1px  1px 0 #000;
# ">
# Econ 430
# </h2>
#
# <h3 style="
#     font-family: Garamond;
#     font-size: 20px;
#     color: #2774AE;
#     font-style: italic;
# ">
# Jacob Williams, Josh Kentworthy, and Ignacio Ramirez
# </h3>
#
# <h3 style="
#     font-family: Garamond;
#     font-size: 20px;
#     color: #000000;
#     font-style: italic;
# ">
# University of California, Los Angeles
# </h3>
#
# <h3 style="
#     font-family: Garamond;
#     font-size: 20px;
#     color: #000000;
#     font-style: italic;
# ">
# November 20, 2025
# </h3>

# %% [markdown]
# <h3 style="font-family: Garamond; font-weight: bold; font-size: 20px; margin-bottom: 0.4em;">
# Original Paper
# </h3>
#
# <p style="font-family: Georgia; font-size: 15px; line-height: 1.5;">
#
# <strong>Fama, Eugene F., &amp; French, Kenneth R.</strong><br>
# <em>A Five-Factor Asset Pricing Model.</em><br>
# <em>Journal of Financial Economics</em>, <strong>116</strong>(1), 1–22. (2015)
#
# </p>

# %% [markdown]
# <h1 style="font-family: Garamond; font-weight: bold; font-size: 28px; margin-bottom: 0.4em;">
# 1. Original Study Summary
# </h1>
#
# <h2 style="font-family: Garamond; font-weight: bold; font-size: 20px; margin-bottom: 0.3em;">
# (a) Research Question: Clearly state the paper’s main research question and economic motivation
# </h2>

# %% [markdown]
# Modern asset-pricing began with a simple premise: if markets are competitive and information flows freely, prices should adjust to news and leave no predictable profit opportunities. This idea is what became the **Efficient Market Hypothesis (EMH)**. EMH emerged in the 1950s and 60s out of early empirical work showing that stock returns had almost no autocorrelation, suggesting prices behave like a fair game responding only to new information.
#
# A decade later, Sharpe (1964) and Lintner (1965) formalized the first equilibrium model linking risk to expected returns: the **Capital Asset Pricing Model (CAPM)**. Its prediction was:
#
# <h4 style="font-family: Garamond; font-weight: bold; font-size: 18px; margin-bottom: 0.2em;">
# (1) CAPM Formula
# </h4>
#
#
# $$
# E[R_i] - R_f = \beta_i\,(E[R_M] - R_f)
# $$
#
# CAPM originally told us that one thing explains expected returns: **market risk**.
#
# With **beta** as the sole predictor of cross-sectional differences in average returns. For 20 years this model remained empirically reasonable.
#
# ---
#
# But as Fama repeatedly emphasizes, CAPM’s “golden age” was short. By the early 1980s and into the 1990s, empirical papers accumulated showing that the relationship between market betas and average returns was basically "flat", but according to CAPM it couldn't be flat, average returns should increase with market beta. So beta alone could not explain average returns sorted on firm **size** (Banz 1981), **earnings-price ratios** (Basu 1977), **leverage** (Bhandari 1988), or **book-to-market** (Rosenberg, Reif & Lanstein 1985).
#
# These accumulating anomalies eventually shifted professional consensus. In a 1992 New York Times article based on a phone interview with Eugene Fama, he stated that “beta as the sole variable explaining returns on stocks is dead” (Berg 1992).
#
# These empirical failures exposed a deeper theoretical problem: CAPM offered too narrow a representation of risk. Asset pricing models required additional dimensions to explain why some portfolios earned persistently higher returns than others.
#
# When Eugene Fama and Kenneth French aimed at capturing these missing dimensions, they developed the **Fama–French Three-Factor Model (1993)**, which looked at the two biggest anomalies for the CAPM, which was it's inability to explain small stock returns and the difference between value and growth stock returns. That's why in the Three Factor Model they augmented the market factor with size (SMB: small minus big) and value (HML: high minus low book-to-market):
#
# <h4 style="font-family: Garamond; font-weight: bold; font-size: 18px; margin-bottom: 0.2em;">
# (2) Fama-French Three Factor Formula
# </h4>
#
# $$
# R_i - R_f = \alpha_i + \beta_i (R_M - R_f) + s_i\,\text{SMB} + h_i\,\text{HML} + \varepsilon_i
# $$
#
# <h4 style="font-family: Garamond; font-weight: bold; font-size: 18px; margin-bottom: 0.2em;">
# Research Question of the Three-Factor Model
# </h4>
#
# The central question motivating the Three-Factor Model is whether **size (SMB)** and **value (HML)** contain systematic information about expected returns that the CAPM’s single beta cannot capture. In other words:
#
# **Can the cross section of average stock returns be better explained by adding size and value factors to the market factor, thereby accounting for the persistent return premiums observed for small firms and high book to market firms?**
#
# After the Three-Factor Model (1993), Fama and French showed that the size and value factors **SMB** and **HML** captured important patterns that the CAPM could not explain. Small firms earned higher average returns than big firms (**size premium**), and high book to market firms earned higher returns than growth firms (**value premium**). In the three-factor framework, these effects appear through the parameters $( s_i )$ and $( h_i )$:
#
#  $( s_i > 0 )$ for small firms and $( s_i < 0 )$ for big firms
#  $( h_i > 0 )$ for high book-to-market (value) firms
#
# But the model was still incomplete as evident by Novy-Marx (2012), Titman, Wei and Xie (2004) which say that the Three Factor is incomplete model for expected returns because its three factors miss much of the variation in average returns related to profitability and investment.
#
# ---
# A natural next step after the Three-Factor Model was to ask whether basic valuation logic could justify adding additional predictors. Under the standard dividend-discount framework,
#
# $
# m_t = \sum_{k=1}^{\infty} \frac{E_t[d_{t+k}]}{(1+r)^k}
# $
#
# **holding other characteristics constant**, a firm with higher expected profitability should have a higher required return $( r )$. Put differently, if two firms have similar book equity $( B )$ but one has higher expected earnings or cash flows, the valuation identity implies a positive link between profitability and expected returns. Empirically, portfolios sorted on operating profitability $(\text{OP})$ showed exactly this pattern.
#
# Likewise, investment behavior carries information about expected returns. In standard steady state valuation, higher investment $( I_t )$ relative to assets $( A_t )$ (i.e., high asset growth) is typically associated with lower expected returns because firms invest more when their marginal $( q )$ is low. This motivates a negative relation between investment and expected returns. Fama and French operationalize this using the investment factor:
#
# $
# \text{CMA} = R_{\text{Conservative}} - R_{\text{Aggressive}}
# $
#
# Combining theis economic motivation, Fama and French extend the Three-Factor Model by adding profitability and investment factors:
#
# <h4 style="font-family: Garamond; font-weight: bold; font-size: 18px; margin-bottom: 0.2em;">
# (3) Fama-French Five Factor Formula
# </h4>
#
# $$
# R_{i,t} - R_{f,t}
# = \alpha_i
# + \beta_i \left(R_{M,t} - R_{f,t}\right)
# + s_i\,\text{SMB}_t
# + h_i\,\text{HML}_t
# + r_i\,\text{RMW}_t
# + c_i\,\text{CMA}_t
# + \varepsilon_{i,t}.
# + $$
# <h4 style="font-family: Garamond; font-weight: bold; font-size: 18px; margin-bottom: 0.2em;">
# Research Question of the Five-Factor Model
# </h4>
#
# The Five-Factor Model asks whether **profitability (RMW)** and **investment (CMA)**, two characteristics central to standard valuation theory, further improve our understanding of the cross-section of expected returns beyond size and value. Meaning:
#
# **Do differences in firm's profitability and investment behavior help explain average returns in a way that is consistent with basic discounted cash flow logic, and do these two factors capture return patterns not absorbed by the original three factors?**
#
# The Five-Factor Model tests whether expected returns vary **positively with profitability** and **negatively with investment**, completing the move from anomaly driven factors toward factors grounded in economic fundamentals.
#
# In this Five Factor Model, the economic prediction and what the data confirm is that **average returns vary positively with profitability** $(r_i > 0)$ **and negatively with investment** $(c_i < 0)$.

# %% [markdown]
# <h2 style="font-family: Garamond; font-weight: bold; font-size: 20px; margin-bottom: 0.3em;">
# (b) Theoretical Framework: Summarize the economic theory underlying the analysis
# </h2>

# %% [markdown]
# <h2 style="font-family: Garamond; font-weight: bold; font-size: 20px; margin-bottom: 0.3em;">
# 0. CAPM
# </h2>
#
# The Capital Asset Pricing Model (CAPM) predicts that expected excess returns depend only on market risk:
#
# $E[R_i - R_f] = \beta_i \, E[R_M - R_f].$
#
# Empirically, we estimate:
#
# $R_{i,t} - R_{f,t}
# = \alpha_i + \beta_i (R_{M,t} - R_{f,t}) + \varepsilon_{i,t}.$
#
#
# **CAPM said that market beta *$\beta$* should fully explain expected returns**, leaving no room for abnormal performance *$\alpha$*.
# In theory, **$\alpha$** is the extra return beyond what your risk exposure predicts, the “bonus” return, but it shouldn’t exist if the model is good at explaining returns.
#
# However, when researchers tested CAPM, they found return patterns, especially for small firms and high book-to-market firms that produced large, persistent **abnormal returns** (*$\alpha$*).
# These anomalies revealed that CAPM was missing important sources of risk, motivating the move to the **Three-Factor Model**.
#
#
# ---
#
# <h2 style="font-family: Garamond; font-weight: bold; font-size: 20px; margin-bottom: 0.3em;">
# 1. Fama–French Three-Factor Model
# </h2>
#
# <p style="text-align: center; font-family: Garamond; font-weight: bold; font-size: 20px;">
# 3 Factor Regression
# </p>
#
# $$
# R_{i,t} - R_{f,t}
# = \alpha_i
# + b_i (R_{M,t} - R_{f,t})
# + s_i \, \text{SMB}_t
# + h_i \, \text{HML}_t
# + \varepsilon_{i,t}.
# $$
#
# **Outcome variable:**
# $(R_{i,t} - R_{f,t})$: excess return on portfolio $i$ at time $t$.
#
# **X Variables:**
#
# **Market $(R_M - R_f)$**
# Represents aggregate systematic risk (the original CAPM beta risk).
#
# **SMB (Size)**
# Small firms tend to have more volatile and cyclical earnings, weaker balance sheets, and greater sensitivity to recessions.
# Higher exposure to SMB reflects greater “small-firm risk,” so portfolios with larger SMB loadings should earn higher expected returns:
#
# $s_i \uparrow \;\Rightarrow\; E[R_i] \uparrow$
#
# **HML (Value)**
# High Book-to-Market (value) firms typically have low prices relative to fundamentals, persistently weak earnings, and characteristics associated with financial distress.
# Low Book-to-Market (growth) firms tend to be more profitable and less distressed.
#
# If markets price risk rationally, portfolios with higher HML loadings are more exposed to “value/distress” risk and therefore earn higher expected returns:
#
# $h_i \uparrow \;\Rightarrow\; E[R_i] \uparrow$
#
# The three-factor model is thus a **risk-based extension of CAPM** that absorbs the size and value patterns left unexplained by beta alone.
#
# ---
#
# <h2 style="font-family: Garamond; font-weight: bold; font-size: 20px; margin-bottom: 0.3em;">
# 2. Fama–French Five-Factor Model
# </h2>
#
# <p style="text-align: center; font-family: Garamond; font-weight: bold; font-size: 20px;">
# 5 Factor Regression
# </p>
#
# $$
# R_{i,t} - R_{f,t}
# = \alpha_i
# + b_i (R_{M,t} - R_{f,t})
# + s_i \, \text{SMB}_t
# + h_i \, \text{HML}_t
# + r_i \, \text{RMW}_t
# + c_i \, \text{CMA}_t
# + \varepsilon_{i,t}.
# $$
#
# **Outcome variable:**
# $(R_{i,t} - R_{f,t})$: excess return on portfolio $i$ at time $t$.
#
# **X Variables:**
#
# Market $(R_M - R_f)$ – aggregate systematic risk.
#
# SMB – small-minus-big size factor.
#
# HML – high-minus-low value factor.
#
# **RMW – Robust minus Weak profitability.**
#
# **CMA – Conservative minus Aggressive investment.**
#
# ---
#
# <h3 style="font-family: Garamond; font-weight: bold; font-size: 20px; margin-bottom: 0.3em;">
# Valuation Economic Interpretation
# </h3>
#
# The Five-Factor Model is built directly from a simple valuation identity: a stock’s price must equal the discounted value of its future cashflows. In the dividend discount model,
#
# $$
# m_t = \sum_{\tau=1}^{\infty} \frac{E(d_{t+\tau})}{(1+r)^\tau},
# $$
#
# the price *must* reflect expectations of future dividends and the discount rate $r$, the stock’s long-run expected return. If two firms are expected to pay the same future dividends but one is cheaper today, the cheaper firm must have a higher expected return. This is the basic insight behind why valuation ratios like B/M forecast returns.
#
# Miller and Modigliani (1961) show that the same logic applies to total equity, where cashflows can be decomposed into earnings minus investment:
#
# $$
# M_t = \sum_{\tau=1}^{\infty}
# \frac{E(Y_{t+\tau} - dB_{t+\tau})}{(1+r)^\tau},
# $$
#
# $$
# \frac{M_t}{B_t}
# =
# \sum_{\tau=1}^{\infty}
# \frac{E(Y_{t+\tau} - dB_{t+\tau})}{B_t (1+r)^\tau}.
# $$
#
# The third equation tells us that expected returns depend on three ingredients:
#
# **(1) Valuation:** higher $B_t/M_t$ (cheap stocks) imply higher expected returns.
#
# **(2) Profitability:** higher expected earnings $E(Y_{t+\tau})$ imply a higher expected return.
#
# **(3) Investment:** higher expected growth in book equity $dB_{t+\tau}$ implies a lower expected return, because investing heavily today raises future earnings but lowers near-term cashflows available to shareholders.
#
# The economic challenge, historically, was finding real-world proxies for expected profitability and expected investment. Novy-Marx (2013) shows that operating profitability strongly predicts average returns, and Aharoni, Grundy, and Zeng (2013) show that investment does as well. These patterns are only weakly captured by the original three-factor model.
#
# Fama and French’s key insight is that RMW and CMA are the *natural* empirical proxies implied by the valuation decomposition: RMW captures differences in expected profitability, and CMA captures differences in expected investment. Together, they extend the three-factor model so that it lines up with the fundamental accounting identity linking prices, earnings, and investment.
#
# ---
#
# **Profitability (RMW)**
#
# Higher expected earnings raise the numerator of the valuation identity.
# To keep the observed price fixed, the discount rate (expected return) must rise:
#
# $E(Y_{t+\tau}) \uparrow \;\Rightarrow\; r \uparrow$
#
# Portfolios with higher RMW loadings are more exposed to profitability risk and should earn higher expected returns:
#
# $r_i \uparrow \;\Rightarrow\; E[R_i] \uparrow$
#
# **Investment (CMA)**
#
# Higher investment increases future book equity, reducing net cashflow $(Y_{t+\tau} - dB_{t+\tau})$ for a given price.
# This pushes the required return **down**:
#
# $dB_{t+\tau} \uparrow \;\Rightarrow\; r \downarrow$
#
# Portfolios with higher CMA loadings behave like firms that invest conservatively (low $dB$) and thus carry higher expected returns than aggressively investing firms:
#
# $c_i \uparrow \;\Rightarrow\; E[R_i] \downarrow$

# %% [markdown]
# <h2 style="font-family: Garamond; font-weight: bold; font-size: 20px; margin-bottom: 0.3em;">
# (c) Methodology: Econometric Approach, Model Specification, and Estimation
# </h2>
#
# The econometric approach follows the standard Fama–French asset pricing methodology. We estimate factor loadings (aka the time-series regression slopes) using time-series OLS regressions of portfolio excess returns on factor returns, and we evaluate model performance through the main diagnostics used in Fama and French (1993, 2015): the magnitude and significance of intercepts, the signs and t-statistics of factor loadings, the regression $R^2$ values that indicate how much common variation the factors capture, and the joint GRS test of whether all alphas are zero. We also compare models using the variance of the estimated alphas $alpha_i$, and examine whether adding profitability and investment factors reduces the magnitude and cross-sectional variance of these pricing errors across the 25 portfolio and 32 portfolio sorts.
#
# We estimate factor loadings using time-series Ordinary Least Squares (OLS) regressions of portfolio excess returns on factor returns. For each test portfolio $i$, we run a separate regression of monthly excess returns $(R_{it} - R_{Ft})$ on the factor returns. This produces the intercept $(a_i)$ and the slope coefficients $(b_i, s_i, h_i, r_i, c_i)$, which measure the portfolio’s exposure to the market, size, value, profitability, and investment factors.
#
# Our left side (Y) portfolios follow the Fama and French (2015) design. Portfolios are formed from independent sorts on Size, Book-to-Market (B/M), Operating Profitability (OP), and Investment (Inv), and are then used as LHS assets in the regressions:
#
# - 25 Size–B/M portfolios (5 x 5 sort on Size and B/M)
# - 25 Size–OP portfolios (5 x 5 sort on Size and operating profitability)
# - 25 Size–Inv portfolios (5 x 5 sort on Size and investment)
# - 32 Size–B/M–OP portfolios (2 x 4 x 4 sort on Size, B/M, and OP)
# - 32 Size–B/M–Inv portfolios (2 x 4 x 4 sort on Size, B/M, and investment)
# - 32 Size–OP–Inv portfolios (2 x 4 x 4 sort on Size, OP, and investment)
#
# For each of these six 'left side' sets, we estimate the same sequence of time-series regressions on the right side (x) factors:
#
# - CAPM: market excess return only
# - Three-Factor Model: market, SMB, HML
# - Five-Factor Model: market, SMB, HML, RMW, CMA
#
# This means, for example, that the 25 Size–B/M portfolios generate 25 separate CAPM regressions, 25 three-factor regressions, and 25 five-factor regressions, and similarly for each of the other 25 portfolio and 32 portfolio sorts. In total, this yields hundreds of time-series regressions, as in Fama and French (2015).
#
# In the original three-factor paper (Fama and French, 1993), the same time-series OLS framework is applied to 25 Size–B/M stock portfolios and 7 bond portfolios. In our replication, we focus on the equity portfolios and estimate the three-factor model and the five-factor model on the same sets of stock portfolios, so model comparisons are based on identical LHS assets.
#
# <h3 style="font-family: Garamond; font-weight: bold; font-size: 18px; margin-bottom: 0.3em;">
# Model Specification
# </h3>
#
# The Three-Factor Model is estimated using:
#
# $$
# R_{it} - R_{Ft}
# = a_i
# + b_i (R_{Mt} - R_{Ft})
# + s_i \, SMB_t
# + h_i \, HML_t
# + e_{it}.
# $$
#
# For the Three-Factor Model, we follow the original Fama and French (1993) design and estimate the model **only** on the 25 Size–B/M portfolios. These portfolios are constructed from a 5 x 5 independent sort on Size and Book-to-Market and were the primary equity test assets used in the original three-factor paper.
#
# Thus, the Three-Factor Model produces **25 separate time-series regressions**, one for each Size–B/M portfolio.
#
# <br>
#
# The Five-Factor Model extends the Three-Factor Model by including profitability and investment:
#
# $$
# R_{it} - R_{Ft}
# = a_i
# + b_i (R_{Mt} - R_{Ft})
# + s_i \, SMB_t
# + h_i \, HML_t
# + r_i \, RMW_t
# + c_i \, CMA_t
# + e_{it}.
# $$
#
# Once we move to the Five-Factor Model, we expand the left-hand-side (LHS) assets to match the full testing design of Fama and French (2015). Profitability and investment sorts did not exist in the earlier three-factor model, so they enter the analysis only at this stage.
#
# The Five-Factor Model is estimated on the six portfolio families introduced in Fama and French (2015):
#
# - 25 Size–B/M portfolios
# - 25 Size–OP portfolios
# - 25 Size–Inv portfolios
# - 32 Size–B/M–OP portfolios
# - 32 Size–B/M–Inv portfolios
# - 32 Size–OP–Inv portfolios
#
# Each portfolio in each sort generates one time-series regression. This produces **171 separate regressions** per model specification and allows direct comparison of the Three-Factor and Five-Factor Models on a greatly expanded set of characteristics.
#
# This structure mirrors the original papers: the Three-Factor Model is evaluated on the traditional 25 Size–B/M portfolios, while the Five-Factor Model is evaluated on the complete set of 25-portfolio and 32-portfolio sorts that incorporate profitability and investment information.
#
#
# The coefficients $(b_i, s_i, h_i, r_i, c_i)$ represent exposures to the underlying economic risks, while $(a_i)$ measures the model’s pricing error for portfolio $i$.
#
# Each coefficient captures a different dimension of risk:
#
# - **$b_i$ (Market):** sensitivity to the excess market return $(R_M - R_f)$.
# - **$s_i$ (Size / SMB):** exposure to the return spread between small and big firms.
# - **$h_i$ (Value / HML):** exposure to the return spread between high and low book-to-market firms.
# - **$r_i$ (Profitability / RMW):** sensitivity to the return spread between robust and weak profitability firms.
# - **$c_i$ (Investment / CMA):** sensitivity to the return spread between conservative and aggressive investment firms.
#
# Together, these loadings summarize how each portfolio co-moves with the factor premiums emphasized by Fama and French.
#
#
# <h3 style="font-family: Garamond; font-weight: bold; font-size: 18px; margin-bottom: 0.3em;">
# Sample
# </h3>
#
# We use **monthly portfolio returns** and **monthly factor returns**, consistent with the original papers. All portfolio returns are converted to excess returns using the one-month Treasury bill rate. Our sample period matches the availability of the Fama–French Five-Factor dataset, and all portfolios are value-weighted as the author states in the data library.
#
# The 25 portfolio sorts come from independent 5 x 5 sorts on Size and B/M, Size and OP, and Size and Inv. The 32 portfolio sorts come from 2 x 4 x 4 sorts on Size, B/M, and OP; Size, B/M, and Inv; and Size, OP, and Inv. These are the same portfolio definitions used in Fama and French (2015) to evaluate the three-factor and five-factor models.
#
#
#
# <h3 style="font-family: Garamond; font-weight: bold; font-size: 18px; margin-bottom: 0.3em;">
# Estimation Technique
# </h3>
#
# To test whether all alphas are jointly zero within a given portfolio set (for example, all 25 Size–B/M portfolios), we use the **GRS test** of Gibbons, Ross, and Shanken (1989), following Fama and French (2014). The GRS statistic is computed for each model and each of the six portfolio families.
#
# Regression parameters are estimated using Ordinary Least Squares (OLS), consistent with Fama and French (1993, 2015). Statistical inference centers on the significance of the factor coefficients and the intercepts (alphas), where a correctly specified model implies $a_i = 0$ for all test portfolios. We report conventional OLS $t$-statistics, matching the approach in the original studies.
#
# We also evaluate:
#
# - whether the estimated alphas $(a_i)$ differ significantly from zero,
# - the explanatory power of each regression (adjusted $R^2$),
# - whether the signs and magnitudes of the factor loadings align with economic intuition,
# - and the overall fit of the model across different portfolio sets.

# %% [markdown]
# <h2 style="font-family: Garamond; font-weight: bold; font-size: 20px; margin-bottom: 0.3em;">
# (d) Key Variables: Dependent and Independent Variables
# </h2>
#
# The dependent variable in all regressions is the **excess return on portfolio $i$ in month $t$**, defined as:
#
# $$
# Y_{it} = R_{it} - R_{Ft}.
# $$
#
# Here, $R_{it}$ is the value-weighted return on portfolio $i$ for month $t$, and $R_{Ft}$ is the one-month Treasury bill rate. Consistent with Fama and French (1993, 2015), all left hand side (LHS) portfolios are formed each June using NYSE breakpoints and their returns are computed monthly from July of year $t$ to June of year $t+1$. Value-weighted returns are computed as:
#
# $$
# R_{it} = \sum_{j \in \mathcal{P}_i} w_{j,t-1} R_{jt},
# \qquad
# \sum_{j \in \mathcal{P}_i} w_{j,t-1} = 1.
# $$
#
# Our Y-portfolios follow the full Fama and French (2015) design. The test assets include:
#
# - 25 Size–B/M portfolios
# - 25 Size–OP portfolios
# - 25 Size–Inv portfolios
# - 32 Size–B/M–OP portfolios
# - 32 Size–B/M–Inv portfolios
# - 32 Size–OP–Inv portfolios
#
# These portfolios produce large monotonic spreads across Size, Book to Market, Operating Profitability, and Investment. The key characteristics the models aim to explain.
#
# <br>
#
# <h3 style="font-family: Garamond; font-weight: bold; font-size: 18px; margin-bottom: 0.3em;">
# Independent Variables (X): Factor Returns and Economic Interpretation
# </h3>
#
# The right hand side variables are the Fama–French factor returns. Each factor is a zero cost long–short portfolio intended to proxy for a systematic source of risk in expected returns. For each portfolio $i$, the estimated coefficients $(b_i, s_i, h_i, r_i, c_i)$ measure exposure to each factor.
#
# <br>
#
# **Market Factor (MKT):**
# $$
# X_{1t} = R_{Mt} - R_{Ft}.
# $$
# Economic interpretation: $b_i$ is the portfolio’s market beta, its sensitivity to aggregate economic risk.
#
# <br>
#
# **Size Factor (SMB):**
# $$
# X_{2t} = SMB_t = R_{\text{Small},t} - R_{\text{Big},t}.
# $$
# Economic interpretation: $s_i$ measures whether portfolio $i$ behaves like small firms ($s_i > 0$) or big firms ($s_i < 0$), reflecting the size premium.
#
#
#
# <br>
#
# **Value Factor (HML):**
# $$
# X_{3t} = HML_t = R_{\text{High B/M},t} - R_{\text{Low B/M},t}.
# $$
#
# HML measures the return premium investors earn for holding **value firms** rather than **growth firms**.
#
# A **positive** $h_i$ means the portfolio behaves like value stocks and earns compensation for value-related risk.
#
# A **negative** means the portfolio behaves more like growth stocks, which have lower expected returns.
#
#
# <br>
#
# **Profitability Factor (RMW):**
# $$
# X_{4t} = RMW_t = R_{\text{Robust OP},t} - R_{\text{Weak OP},t}.
# $$
#
# RMW measures the return premium associated with **profitability**, specifically the difference between firms with **robust operating profitability** and those with **weak profitability**.
#
# A **positive** $r_i$ means the portfolio behaves like highly profitable firms and earns compensation for profitability related risk.
#
# A **negative** means the portfolio behaves like weak profitability firms, which have lower and more volatile cash flows and therefore lower expected returns.
#
#
# <br>
#
# **Investment Factor (CMA):**
# $$
# X_{5t} = CMA_t = R_{\text{Conservative Inv},t} - R_{\text{Aggressive Inv},t}.
# $$
# Economic interpretation: $c_i$ reflects exposure to the investment premium. Conservatively investing firms earn higher expected returns than aggressively investing firms unless the latter have strong profitability.
#
# <br>
#
# Together, these factor loadings summarize how each portfolio co-moves with the underlying economic risks emphasized by Fama and French. A correctly specified factor model should absorb these systematic risks and leave intercepts that satisfy:
#
# $$
# a_i = 0 \quad \forall i.
# $$

# %% [markdown]
# <h2 style="font-family: Garamond; font-weight: bold; font-size: 20px; margin-bottom: 0.3em;">
# (e) Main Findings: Authors’ Primary Empirical Results and Conclusions
# </h2>
#
# The central empirical finding of Fama and French (2015) is that the Five-Factor Model offers a substantial improvement over the original Three-Factor Model. As they write, *“A five-factor model directed at capturing the size, value, profitability, and investment patterns in average stock returns performs better than the three-factor model of Fama and French (1993).”* The addition of profitability (RMW) and investment (CMA) factors sharply increases explanatory power and reduces the magnitude of pricing errors across most portfolio sets.
#
# Despite this improvement, the model is not a perfect description of the data. The GRS test rejects the model as a complete asset-pricing model, even though its economic fit is strong. The authors note, *“The GRS test easily rejects a five-factor model directed at capturing these patterns, but we estimate that the model explains between 71% and 94% of the cross-section variance of expected returns for the Size, B/M, OP, and Inv portfolios we examine.”* In other words, the model is statistically rejected but economically powerful.
#
# One of the most notable findings is that the profitability and investment factors render the original value factor (HML) redundant. The authors state directly that, *“With the addition of profitability and investment factors, the value factor of the FF three-factor model becomes redundant for describing average returns in the sample we examine.”* This redundancy arises because HML’s high average return can be almost entirely explained by its exposures to the other factors:
# *“…our results suggest that HML is a redundant factor in the sense that its high average return is fully captured by its exposures to $R_M - R_F$, SMB, and especially RMW and CMA.”*
#
# This result highlights the theoretical success of the new factors:
# - **Profitability (RMW)** is strongly and positively related to average returns.
# - **Investment (CMA)** is strongly negatively related to average returns (firms investing aggressively earn lower returns).
#
# Together, these two factors subsume the information HML was capturing about cash-flow risk and investment behavior.
#
# However, the Five-Factor Model also has a clear and well-defined failure. Fama and French describe this as the model’s *“lethal”* problem: its inability to explain the very low average returns on certain small, distressed firms. These are portfolios made up of small firms that **invest heavily despite having low profitability**, and they consistently generate pricing errors that the model cannot account for. As the authors write, *“Portfolios of small stocks with negative exposures to RMW and CMA are the biggest asset pricing problem in four of the six sets of LHS portfolios examined here.”* They conclude, *“…we find that the lethal portfolios contain small stocks of firms that invest a lot despite low profitability.”*
#
# In summary, the main empirical outcomes are:
#
# - The Five-Factor Model substantially improves upon the Three-Factor Model.
# - Profitability (RMW) is a powerful, economically meaningful factor with a strong positive relation to returns.
# - Investment (CMA) is also important, though it introduces challenges in capturing low-return, high-investment small firms.
# - The value factor (HML) becomes redundant once RMW and CMA are introduced.
# - Despite its successes, the model is still rejected statistically and fails most clearly for small, unprofitable, high-investment firms.
#
# These findings form the basis of the paper’s contribution: a more complete but still imperfect model of the cross-section of expected returns.

# %% [markdown]
# <h2 style="font-family: Garamond; font-weight: bold; font-size: 20px; margin-bottom: 0.3em;">
# (f) Contribution: Explain what gap in the literature this paper addresses
# </h2>
#
# The paper addresses two seperate gaps in the literature of previous research. The first being the inital gap in the Capital Asset Pricing Model that was addressed and framed into what is known as the "Three-Factor Model." The second being the gap that was later noted in the "Three-Factor Model"  that was addressed and framed into what is known as the "Five-Factor Model."
#
# <h3 style="font-family: Garamond; font-weight: bold; font-size: 18px; margin-bottom: 0.3em;">
# First Gap: Shortcomings of the CAPM Model
# </h3>
#
# The initial gap addressed by the Fama-French framework lies in the failures of the Capital Asset Pricing Model (CAPM). The CAPM predicted that a stock's market beta, $\beta_1$, alone should explain the cross-section of expected stock returns.
#
# **The CAPM Anomaly**
#
# This prediction was contradicted by early empirical evidence (anomalies) showing that average returns were related to characteristics other than market beta. The Fama-French (1993) paper and subsequent literature documented that average returns showed patterns related to variables like:
#
# - **Firm Size**
#
# - **Earnings-to-Price Ratios**
#
# - **Leverage**
#
# - **Book-to-Market Equity Ratio ($B/M$)**
#
# The Fama-French three-factor model was created to close this gap by adding the Size (SMB) and Value (HML) factors to the market factor ($R_M−R_F$) to capture the most prominent anomalies left unexplained by the CAPM.
#
#
# <h3 style="font-family: Garamond; font-weight: bold; font-size: 18px; margin-bottom: 0.3em;">
# Second Gap: The Incompleteness of the Three-Factor Model
# </h3>
#
#
# The second, and more direct, gap addressed by the Fama-French (2015) paper concerns the incompleteness of the three-factor model itself.
#
# **The Profitability and Investment Challenge**
#
# Even after the development of the three-factor model, subsequent research continued to find variation in average stock returns that were left unexplained by the $R_M−R_F$, $SMB$, and $HML$ factors. This challenged the three-factor model's claim to capture all relevant cross-sectional variation.
#
# The authors note that evidence began to accumulate showing that profitability and investment added to the description of average returns provided by $B/M$.
#
# - Novy-Marx (2013) identified a proxy for expected profitability that showed a strong relation to average return.
#
# - Aharoni, Grundy, and Zeng (2013) documented a weaker, but statistically reliable, relation between investment and average return.
#
# - The overall challenge was that "much of the variation in average returns related to profitability and investment is left unexplained by the three-factor model".
#
# The research challenge posed by the underlying valuation equation (the Dividend Discount Model) was to "identify proxies for expected earnings and investments".
#
#
# **Closing the Gap:**
# The Fama-French (2015) paper closes this second gap by creating and testing a model that explicitly adds these two factors, Profitability (RMW) and Investment (CMA) to the existing three factors. The explicit goal was to capture the profitability and investment patterns that the three-factor model missed.

# %% [markdown]
# ___

# %% [markdown]
# <h1 style="font-family: Garamond; font-weight: bold; font-size: 28px; margin-bottom: 0.4em;">
# 2. Data Acquisition
# </h1>

# %% [markdown]
# <h2 style="font-family: Garamond; font-weight: bold; font-size: 20px; margin-bottom: 0.3em;">
# (a) Data Sources from the Kenneth R. French Data Library
# </h2>
#
# <h3 style="font-family: Garamond; font-weight: bold; font-size: 18px; margin-bottom: 0.3em;">
# Source:
# </h3>
#
# **Kenneth R. French Data Library**
# Tuck School of Business, Dartmouth College
# https://mba.tuck.dartmouth.edu/pages/faculty/ken.french/data_library.html
#
# Although the Library presents information in clean portfolio-level form, all underlying data come from *CRSP* (monthly stock returns and market equity) and *Compustat* (accounting fundamentals such as book equity, operating profitability, and investment).
#
# ---
#
# <h3 style="font-family: Garamond; font-weight: bold; font-size: 18px; margin-bottom: 0.3em;">
# Pulling the Portfolio and Factor Data:
# </h3>
#
# *Notes:* Portfolio breakpoints are based on NYSE firms to ensure stable sorting thresholds and reduce micro-cap distortions. Final portfolios include eligible stocks from NYSE, AMEX, and NASDAQ. Unless otherwise stated, all portfolio returns are value-weighted. Factor construction follows the standard methodology described in Fama and French (1993, 2015). Although the Data Library provides ex.Dividend, weekly, and daily return files, this replication uses only the standard monthly return series. All data were downloaded in CSV format.
#
# | Portfolio / Factor | Data Source & Construction Details |
# |------------------|------------------------------------|
# | **25-Portfolio Bivariate Sorts (5×5)** | Sourced from:<br><span style="color:#1f3a8a; font-weight:600;">25 Portfolios Formed on Size and Book-to-Market (5×5)</span><br><span style="color:#1f3a8a; font-weight:600;">25 Portfolios Formed on Size and Operating Profitability (5×5)</span><br><span style="color:#1f3a8a; font-weight:600;">25 Portfolios Formed on Size and Investment (5×5)</span><br><br>Construction: Firms are sorted each June into 5 Size groups and 5 characteristic groups (B/M, OP, or Investment) using NYSE breakpoints. Portfolios are value-weighted and include NYSE, AMEX, and NASDAQ stocks. |
# | **32-Portfolio Three-Way Sorts (2×4×4)** | Sourced from:<br><span style="color:#1f3a8a; font-weight:600;">32 Portfolios Formed on Size, B/M, and OP (2×4×4)</span><br><span style="color:#1f3a8a; font-weight:600;">32 Portfolios Formed on Size, B/M, and Investment (2×4×4)</span><br><span style="color:#1f3a8a; font-weight:600;">32 Portfolios Formed on Size, OP, and Investment (2×4×4)</span><br><br>Construction: Firms are split into Small/Big using the NYSE median, then independently sorted into 4 groups on the remaining characteristics using NYSE breakpoints. Produces 32 value-weighted portfolios per sort. |
# | **Fama–French 5 Factors (2×3)** | Sourced from <span style="color:#1f3a8a; font-weight:600;">Fama/French 5 Factors (2×3)</span>. Constructed from six value-weighted portfolios formed on Size × B/M, Size × OP, and Size × Investment. Factors: MKT, SMB, HML, RMW, CMA. Market includes NYSE/AMEX/NASDAQ CRSP firms; risk-free rate is the 1-month T-bill. |
# | **Fama–French 3 Factors** | Sourced from <span style="color:#1f3a8a; font-weight:600;">Fama/French 3 Factors</span>. Constructed from six value-weighted portfolios formed on Size × Book-to-Market (2×3). Factors: MKT, SMB, HML. Data includes CRSP firms listed on NYSE, AMEX, and NASDAQ. Risk-free rate is the 1-month T-bill. |
#
#
# ---
#
# How The Portfolio Sorts Are Used:
#
# | Purpose in Replication | Dataset Used |
# |------------------------|--------------|
# | **RHS Variables (Factors)** | Fama/French 3 Factors (for the three-factor model)<br>Fama/French 5 Factors (for the five-factor model) |
# | **LHS Variables — Three-Factor Tests** | 25 Portfolios Formed on Size and Book-to-Market (5×5) |
# | **LHS Variables — Five-Factor Tests (Core)** | 25 Portfolios Formed on Size and Book-to-Market (5×5)<br>25 Portfolios Formed on Size and Operating Profitability (5×5)<br>25 Portfolios Formed on Size and Investment (5×5) |
# | **LHS Variables — Five-Factor Robustness Tests** | 32 Size–B/M–OP, 32 Size–B/M–Investment, 32 Size–OP–Investment (2×4×4 sorts) |

# %% [markdown]
# <h2 style="font-family: Garamond; font-weight: bold; font-size: 20px; margin-bottom: 0.3em;">
# (b) Data Processing
# </h2>
#
# This section describes the procedures used to transform the raw data downloaded from the Kenneth R. French Data Library. Although the factor returns (RHS variables) and portfolio returns (LHS variables) originate from different files, they suffer from the same non ideal formatting for replicability of the original paper.
#
# The primary objective of this stage is to replicate the structure and sample period used by Fama and French (2015), who analyze monthly data from July 1963 through December 2013. Since the French Data Library provides continuously updated datasets extending through 2025, all observations after December 2013 were deliberately removed to be within the original analysis.
#
# <h3 style="font-family: Garamond; font-weight: bold; font-size: 18px; margin-bottom: 0.3em;">
# Data Processing Format:
# </h3>
#
# This will apply to both factor returns and portfolio returns because it's all from the same source and they will all follow the same conceptual preprocessing steps:
#
# 1. **Removal of non-data header rows**
#    Raw CSV files include descriptive metadata and explanatory text at the top of the file. These rows were excluded using the `skiprows` argument and further filtered by retaining only observations with valid numeric date identifiers.
#
# 2. **Standardization of variable names**
#    To promote clarity and consistency across datasets, variables were renamed (e.g., `"Mkt-RF"` to `"MKTRF"` and `"Unnamed: 0"` to `"date"`), and only relevant columns were retained.
#
# 3. **Conversion to numeric data types**
#    All factor returns, portfolio returns, and risk-free rates were explicitly converted to numeric formats to prevent implicit coercion during regression estimation.
#
# 4. **Date alignment and merging**
#    Factor and portfolio datasets were merged on the monthly date variable using an inner join. This ensures that each observation corresponds to the same calendar month across all variables.
#
# 5. **Sample truncation to December 2013**
#    After merging, observations occurring after 2013:12 were removed to match the sample window used in the original paper.
#
# 6. **Construction of excess returns**
#    Portfolio excess returns were computed as the difference between portfolio returns and the risk-free rate:
#    $
#    R_{it}^{excess} = R_{it} - R_{ft}
#    $
#    This transformation is required because all Fama–French regressions are estimated in excess return form.
#
# ---
#
# #### Example: 25 Size–Book-to-Market Portfolios
#
# Below is a representative preprocessing example using the 25 Size–Book-to-Market portfolios. This same pipeline is applied to all other portfolio sorts, including Size–Investment, Size–Operating Profitability, and the 32-portfolio three-way sorts.
#
# ```python
# factors = pd.read_csv('data/five_factor_model/factors/5f_data.csv', skiprows=4)
# factors = factors[pd.to_numeric(factors['Unnamed: 0'], errors='coerce').notna()]
# factors = factors.rename(columns={'Unnamed: 0': 'date', 'Mkt-RF': 'MKTRF'})
# factors = factors[['date', 'MKTRF', 'SMB', 'HML', 'RMW', 'CMA', 'RF']]
# factors.iloc[:, 1:] = factors.iloc[:, 1:].apply(pd.to_numeric, errors='coerce')
#
# portSBM = pd.read_csv('data/five_factor_model/portfolios/25_Portfolios_5x5_on_size_BM.csv', skiprows=15)
# portSBM = portSBM.rename(columns={'Unnamed: 0': 'date'})
# portSBM = portSBM[pd.to_numeric(portSBM['date'], errors='coerce').notna()]
# portSBM = portSBM[:-1]
# portSBM.iloc[:, 1:] = portSBM.iloc[:, 1:].apply(pd.to_numeric, errors='coerce')
#
# factors = factors.drop_duplicates(subset='date')
# portSBM = portSBM.drop_duplicates(subset='date')
#
# dataSBM = pd.merge(portSBM, factors, on='date', how='inner')
#
# cutoff_row = dataSBM.index[dataSBM['date'] > '201312'][0]
# dataSBM = dataSBM.iloc[:cutoff_row]
#
# dataSBM['excess'] = dataSBM['SMALL LoBM'] - dataSBM['RF']

# %% [markdown]
# <h2 style="font-family: Garamond; font-weight: bold; font-size: 20px; margin-bottom: 0.4em;">
# (c) - Y Side Summary Statistics
# </h2>
#
# <div style="font-family: Garamond; font-size: 16px; margin-top: 0.2em; margin-bottom: 0.1em;">
# <b>Table 1.</b>
# </div>
#
# <div style="font-family: Garamond; font-size: 15px; line-height: 1.4; margin-bottom: 0.8em;">
# Average monthly percent excess returns for portfolios formed on Size and B/M, Size and OP, Size and Inv; July 1963–December 2013, 606 months.
# </div>

# %%
import pandas as pd
import numpy as np

START_DATE = 196307
END_DATE   = 201312


def load_rf(path="data/five_factor_model/factors/5f_data.csv"):
    df = pd.read_csv(path, skiprows=4)
    df = df[pd.to_numeric(df["Unnamed: 0"], errors="coerce").notna()].copy()
    df = df.rename(columns={"Unnamed: 0": "date"})
    df["date"] = df["date"].astype(int)
    df["RF"] = pd.to_numeric(df["RF"], errors="coerce")
    df = df[["date", "RF"]]
    df = df[(df["date"] >= START_DATE) & (df["date"] <= END_DATE)]
    df = df.drop_duplicates(subset="date")
    return df

rf = load_rf()


def load_portfolio_file(path):
    header_line_index = None
    with open(path, "r", encoding="latin-1") as f:
        for i, line in enumerate(f):
            if line.lstrip().startswith(",SMALL"):
                header_line_index = i
                break
    if header_line_index is None:
        raise ValueError(f"Could not find header line starting with ',SMALL' in {path}")

    df = pd.read_csv(
        path,
        skiprows=header_line_index,
        engine="python"
    )

    first_col = df.columns[0]
    df = df.rename(columns={first_col: "date"})

    df = df[pd.to_numeric(df["date"], errors="coerce").notna()].copy()
    df["date"] = df["date"].astype(int)

    df = df[(df["date"] >= START_DATE) & (df["date"] <= END_DATE)]

    portfolio_cols = df.columns.drop("date")
    df[portfolio_cols] = df[portfolio_cols].apply(pd.to_numeric, errors="coerce")
    df[portfolio_cols] = df[portfolio_cols].replace({-99.99: np.nan, -999: np.nan})

    df = df.drop_duplicates(subset="date")

    return df, list(portfolio_cols)


def build_5x5_panel(path, grid_cols, title):
    df, portfolio_cols = load_portfolio_file(path)

    merged = pd.merge(df, rf, on="date", how="inner")

    merged_excess = merged.copy()
    merged_excess[portfolio_cols] = merged_excess[portfolio_cols].sub(merged_excess["RF"], axis=0)

    avg_excess = merged_excess[portfolio_cols].mean()

    size_labels = ["Small", "2", "3", "4", "Big"]
    col_labels  = ["Low", "2", "3", "4", "High"]

    data = [[avg_excess[c] for c in row] for row in grid_cols]
    panel = pd.DataFrame(data, index=size_labels, columns=col_labels)

    min_val = avg_excess.min()
    max_val = avg_excess.max()

    print(f"\n{title}")
    print(panel.to_markdown(floatfmt=".2f"))
    print(f"Range of mean excess returns in this panel: {min_val:.4f} to {max_val:.4f}")

    return panel


bm_cols = [
    ["SMALL LoBM", "ME1 BM2", "ME1 BM3", "ME1 BM4", "SMALL HiBM"],
    ["ME2 BM1",   "ME2 BM2", "ME2 BM3", "ME2 BM4", "ME2 BM5"],
    ["ME3 BM1",   "ME3 BM2", "ME3 BM3", "ME3 BM4", "ME3 BM5"],
    ["ME4 BM1",   "ME4 BM2", "ME4 BM3", "ME4 BM4", "ME4 BM5"],
    ["BIG LoBM",  "ME5 BM2", "ME5 BM3", "ME5 BM4", "BIG HiBM"],
]

panel_A = build_5x5_panel(
    "data/five_factor_model/portfolios/25_Portfolios_5x5_on_size_BM.csv",
    bm_cols,
    "Panel A: Size–B/M portfolios (average monthly EXCESS returns, %)"
)


op_cols = [
    ["SMALL LoOP", "ME1 OP2", "ME1 OP3", "ME1 OP4", "SMALL HiOP"],
    ["ME2 OP1",    "ME2 OP2", "ME2 OP3", "ME2 OP4", "ME2 OP5"],
    ["ME3 OP1",    "ME3 OP2", "ME3 OP3", "ME3 OP4", "ME3 OP5"],
    ["ME4 OP1",    "ME4 OP2", "ME4 OP3", "ME4 OP4", "ME4 OP5"],
    ["BIG LoOP",   "ME5 OP2", "ME5 OP3", "ME5 OP4", "BIG HiOP"],
]

panel_B = build_5x5_panel(
    "data/five_factor_model/portfolios/25_Portfolios_ME_OP_5x5.csv",
    op_cols,
    "Panel B: Size–OP portfolios (average monthly EXCESS returns, %)"
)


inv_cols = [
    ["SMALL LoINV", "ME1 INV2", "ME1 INV3", "ME1 INV4", "SMALL HiINV"],
    ["ME2 INV1",    "ME2 INV2", "ME2 INV3", "ME2 INV4", "ME2 INV5"],
    ["ME3 INV1",    "ME3 INV2", "ME3 INV3", "ME3 INV4", "ME3 INV5"],
    ["ME4 INV1",    "ME4 INV2", "ME4 INV3", "ME4 INV4", "ME4 INV5"],
    ["BIG LoINV",   "ME5 INV2", "ME5 INV3", "ME5 INV4", "BIG HiINV"],
]

panel_C = build_5x5_panel(
    "data/five_factor_model/portfolios/25_Portfolios_ME_INV_5x5.csv",
    inv_cols,
    "Panel C: Size–Investment portfolios (average monthly EXCESS returns, %)"
)
# Out:
# Panel A: Size–B/M portfolios (average monthly EXCESS returns, %)
# |       |   Low |    2 |    3 |    4 |   High |
# |:------|------:|-----:|-----:|-----:|-------:|
# | Small |  0.27 | 0.79 | 0.80 | 1.03 |   1.11 |
# | 2     |  0.48 | 0.75 | 0.88 | 0.92 |   1.04 |
# | 3     |  0.49 | 0.77 | 0.76 | 0.89 |   1.04 |
# | 4     |  0.59 | 0.60 | 0.69 | 0.87 |   0.88 |
# | Big   |  0.45 | 0.49 | 0.54 | 0.51 |   0.63 |
# Range of mean excess returns in this panel: 0.2681 to 1.1138
#
# Panel B: Size–OP portfolios (average monthly EXCESS returns, %)
# |       |   Low |    2 |    3 |    4 |   High |
# |:------|------:|-----:|-----:|-----:|-------:|
# | Small |  0.57 | 0.96 | 0.87 | 0.95 |   0.86 |
# | 2     |  0.60 | 0.78 | 0.82 | 0.81 |   0.99 |
# | 3     |  0.51 | 0.74 | 0.75 | 0.77 |   0.92 |
# | 4     |  0.58 | 0.65 | 0.68 | 0.70 |   0.81 |
# | Big   |  0.35 | 0.35 | 0.48 | 0.49 |   0.54 |
# Range of mean excess returns in this panel: 0.3469 to 0.9919
#
# ...

# %% [markdown]
# <h2 style="font-family: Garamond; font-weight: bold; font-size: 20px; margin-bottom: 0.4em;">
# Original Table 1 from Fama & French (2015 Paper)
# </h2>
#
# *Average monthly percent excess returns for portfolios formed on Size and B/M, Size and OP, Size and Inv; July 1963–December 2013, 606 months.*
#
# ---
#
# **Panel A: Size–B/M portfolios**
#
# | Size  | Low | 2 | 3 | 4 | High |
# |:------|:----|:--|:--|:--|:-----|
# | Small | 0.26 | 0.81 | 0.85 | 1.01 | 1.15 |
# | 2     | 0.48 | 0.72 | 0.94 | 0.94 | 1.02 |
# | 3     | 0.50 | 0.78 | 0.79 | 0.88 | 1.07 |
# | 4     | 0.60 | 0.57 | 0.71 | 0.85 | 0.86 |
# | Big   | 0.46 | 0.51 | 0.48 | 0.56 | 0.62 |
#
# ---
#
# **Panel B: Size–OP portfolios**
#
# | Size  | Low | 2 | 3 | 4 | High |
# |:------|:----|:--|:--|:--|:-----|
# | Small | 0.56 | 0.94 | 0.90 | 0.95 | 0.88 |
# | 2     | 0.59 | 0.78 | 0.84 | 0.81 | 0.98 |
# | 3     | 0.53 | 0.77 | 0.72 | 0.78 | 0.94 |
# | 4     | 0.57 | 0.65 | 0.63 | 0.70 | 0.82 |
# | Big   | 0.39 | 0.33 | 0.43 | 0.47 | 0.57 |
#
# ---
#
# **Panel C: Size–Inv portfolios**
#
# | Size  | Low | 2 | 3 | 4 | High |
# |:------|:----|:--|:--|:--|:-----|
# | Small | 1.01 | 0.98 | 0.99 | 0.89 | 0.35 |
# | 2     | 0.92 | 0.91 | 0.92 | 0.90 | 0.48 |
# | 3     | 0.90 | 0.93 | 0.81 | 0.82 | 0.50 |
# | 4     | 0.79 | 0.72 | 0.71 | 0.75 | 0.54 |
# | Big   | 0.71 | 0.52 | 0.49 | 0.48 | 0.42 |

# %% [markdown]
# <div style="font-family: Garamond; font-size: 16px; margin-top: 0.2em; margin-bottom: 0.1em;">
# <b>Table 2.</b>
# </div>
#
# <div style="font-family: Garamond; font-size: 15px; line-height: 1.4; margin-bottom: 0.8em;">
# Averages of monthly percent excess returns for value-weight (VW) portfolios formed on (i) Size, B/M, and OP, (ii) Size, B/M, and Inv, and (iii) Size, OP, and Inv; July 1963–December 2013, 606 months.
# </div>

# %%
import pandas as pd
import numpy as np

START_DATE = 196307
END_DATE   = 201312

def load_rf(path="data/five_factor_model/factors/5f_data.csv"):
    factors = pd.read_csv(path, skiprows=4)
    factors = factors[pd.to_numeric(factors["Unnamed: 0"], errors="coerce").notna()].copy()
    factors = factors.rename(columns={"Unnamed: 0": "date"})
    factors["date"] = factors["date"].astype(int)
    factors["RF"] = pd.to_numeric(factors["RF"], errors="coerce")

    rf = factors[["date", "RF"]]
    rf = rf[(rf["date"] >= START_DATE) & (rf["date"] <= END_DATE)]
    rf = rf.drop_duplicates(subset="date")
    return rf

rf = load_rf()

def build_2x4x4_panels(path, skiprows, title,
                        row_labels=("Low", "2", "3", "High"),
                        col_labels=("Low", "2", "3", "High")):
    """
    path      : CSV path for the 32-portfolio file
    skiprows  : number of lines to skip so that the *next* line is the header
    title     : label for printing
    row_labels: characteristic on the rows (OP or Inv)
    col_labels: characteristic on the columns (B/M or OP)
    """

    df_raw = pd.read_csv(path, skiprows=skiprows, engine="python")

    mask_numeric = pd.to_numeric(df_raw.iloc[:, 0], errors="coerce").notna()
    first_bad_idx = df_raw.index[~mask_numeric][0]
    df_raw = df_raw.loc[:first_bad_idx - 1].copy()

    df_raw = df_raw.rename(columns={df_raw.columns[0]: "date"})
    df_raw["date"] = df_raw["date"].astype(int)
    df_raw = df_raw[(df_raw["date"] >= START_DATE) & (df_raw["date"] <= END_DATE)]

    portfolio_cols = df_raw.columns.drop("date")
    df_raw[portfolio_cols] = df_raw[portfolio_cols].apply(pd.to_numeric, errors="coerce")

    df = pd.merge(df_raw, rf, on="date", how="inner")
    df[portfolio_cols] = df[portfolio_cols].sub(df["RF"], axis=0)

    mean_excess = df[portfolio_cols].mean()

    small_cols = portfolio_cols[:16]
    big_cols   = portfolio_cols[16:]

    small_mat = np.array(mean_excess[small_cols]).reshape(4, 4)
    big_mat   = np.array(mean_excess[big_cols]).reshape(4, 4)

    small_panel = pd.DataFrame(small_mat.T, index=row_labels, columns=col_labels)
    big_panel   = pd.DataFrame(big_mat.T,   index=row_labels, columns=col_labels)

    print(f"\n{title} — SMALL (Size) portfolios")
    print(small_panel.to_markdown(floatfmt=".2f"))
    print(f"Min/Max (Small): {small_panel.values.min():.4f} / {small_panel.values.max():.4f}")

    print(f"\n{title} — BIG (Size) portfolios")
    print(big_panel.to_markdown(floatfmt=".2f"))
    print(f"Min/Max (Big): {big_panel.values.min():.4f} / {big_panel.values.max():.4f}")

    return small_panel, big_panel

panelA_small, panelA_big = build_2x4x4_panels(
    "data/five_factor_model/portfolios/32_Portfolios_ME_BEME_OP_2x4x4.csv",
    skiprows=23, 
    title="Panel A: Portfolios formed on Size, B/M, and OP",
    row_labels=("Low OP", "2", "3", "High OP"),
    col_labels=("Low B/M", "2", "3", "High B/M")
)

panelB_small, panelB_big = build_2x4x4_panels(
    "data/five_factor_model/portfolios/32_Portfolios_ME_BEME_INV_2x4x4.csv",
    skiprows=16,
    title="Panel B: Portfolios formed on Size, B/M, and Inv",
    row_labels=("Low Inv", "2", "3", "High Inv"),
    col_labels=("Low B/M", "2", "3", "High B/M")
)

panelC_small, panelC_big = build_2x4x4_panels(
    "data/five_factor_model/portfolios/32_Portfolios_ME_OP_INV_2x4x4_Wout_Div.csv",
    skiprows=24,
    title="Panel C: Portfolios formed on Size, OP, and Inv",
    row_labels=("Low Inv", "2", "3", "High Inv"),
    col_labels=("Low OP", "2", "3", "High OP")
)
# Out:
# Panel A: Portfolios formed on Size, B/M, and OP — SMALL (Size) portfolios
# |         |   Low B/M |    2 |    3 |   High B/M |
# |:--------|----------:|-----:|-----:|-----------:|
# | Low OP  |      0.01 | 0.71 | 0.86 |       0.91 |
# | 2       |      0.63 | 0.82 | 0.85 |       1.08 |
# | 3       |      0.65 | 0.86 | 1.05 |       1.24 |
# | High OP |      0.83 | 1.08 | 1.25 |       1.60 |
# Min/Max (Small): 0.0130 / 1.5978
#
# Panel A: Portfolios formed on Size, B/M, and OP — BIG (Size) portfolios
# |         |   Low B/M |    2 |    3 |   High B/M |
# |:--------|----------:|-----:|-----:|-----------:|
# | Low OP  |      0.19 | 0.32 | 0.40 |       0.55 |
# | 2       |      0.35 | 0.52 | 0.50 |       0.71 |
# | 3       |      0.47 | 0.56 | 0.73 |       0.85 |
# | High OP |      0.51 | 0.57 | 0.80 |       0.59 |
# Min/Max (Big): 0.1898 / 0.8514
#
# Panel B: Portfolios formed on Size, B/M, and Inv — SMALL (Size) portfolios
# |          |   Low B/M |    2 |    3 |   High B/M |
# ...

# %% [markdown]
# <h2 style="font-family: Garamond; font-weight: bold; font-size: 20px; margin-bottom: 0.4em;">
# Original Table 2 from Fama & French (2015 Paper)
# </h2>
#
# *Table 2. Averages of monthly percent excess returns for value-weight (VW) portfolios formed on (i) Size, B/M, and OP, (ii) Size, B/M, and Inv, and (iii) Size, OP, and Inv; July 1963–December 2013, 606 months.*
#
# ---
#
# ## Panel A: Portfolios formed on Size, B/M, and OP
#
# **B/M →**
#
# | OP Level | Small Low | Small 2 | Small 3 | Small High | Big Low | Big 2 | Big 3 | Big High |
# |:----------|:-----------|:---------|:---------|:------------|:---------|:-------|:-------|:----------|
# | Low OP    | 0.03 | 0.72 | 0.84 | 0.93 | 0.24 | 0.23 | 0.37 | 0.60 |
# | 2         | 0.67 | 0.76 | 0.88 | 1.08 | 0.41 | 0.50 | 0.47 | 0.69 |
# | 3         | 0.66 | 0.88 | 1.07 | 1.30 | 0.40 | 0.59 | 0.68 | 0.91 |
# | High OP   | 0.81 | 1.13 | 1.22 | 1.63 | 0.53 | 0.64 | 0.79 | 0.71 |
#
# ---
#
# ## Panel B: Portfolios formed on Size, B/M and Inv
#
# **B/M →**
#
# | Inv Level | Small Low | Small 2 | Small 3 | Small High | Big Low | Big 2 | Big 3 | Big High |
# |:-----------|:-----------|:---------|:---------|:------------|:---------|:-------|:-------|:----------|
# | Low Inv    | 0.69 | 0.99 | 1.18 | 1.23 | 0.58 | 0.70 | 0.62 | 0.77 |
# | 2          | 0.87 | 0.92 | 0.93 | 1.08 | 0.49 | 0.54 | 0.54 | 0.60 |
# | 3          | 0.84 | 0.95 | 1.01 | 0.97 | 0.49 | 0.54 | 0.56 | 0.72 |
# | High Inv   | 0.39 | 0.75 | 0.87 | 1.01 | 0.49 | 0.44 | 0.39 | 0.64 |
#
# ---
#
# ## Panel C: Portfolios formed on Size, OP, and Inv
#
# **OP →**
#
# | Inv Level | Small Low | Small 2 | Small 3 | Small High | Big Low | Big 2 | Big 3 | Big High |
# |:-----------|:-----------|:---------|:---------|:------------|:---------|:-------|:-------|:----------|
# | Low Inv    | 0.85 | 1.01 | 1.19 | 1.27 | 0.63 | 0.66 | 0.79 | 0.70 |
# | 2          | 0.94 | 0.90 | 0.92 | 1.04 | 0.32 | 0.43 | 0.64 | 0.64 |
# | 3          | 0.61 | 0.93 | 0.94 | 1.06 | 0.52 | 0.57 | 0.48 | 0.53 |
# | High Inv   | -0.09 | 0.58 | 0.76 | 0.76 | 0.29 | 0.25 | 0.38 | 0.65 |
#
# ---

# %% [markdown]
# <h2 style="font-family: Garamond; font-weight: bold; font-size: 20px; margin-bottom: 0.4em;">
# 2.(c) - X Side Summary Statistics
# </h2>
#
# <div style="font-family: Garamond; font-size: 15px; line-height: 1.4; margin-bottom: 0.8em;">
# Summary statistics for the right-hand-side (X) variables used in the regression models, including the Fama–French factor returns that explain portfolio excess returns over the sample period.
# </div>

# %% [markdown]
# <h2 style="font-family: Garamond; font-weight: bold; font-size: 18px; margin-bottom: 0.3em;">
# Table 4 [Panel A]:  Averages, standard deviations, and t-statistics for monthly returns
# 2 x 3 Factor
# </h2>

# %%
fdata = pd.read_csv(
    'data/five_factor_model/factors/5f_data.csv',
    skiprows=4
)

fdata = fdata.rename(columns={'Unnamed: 0': 'date', 'Mkt-RF': 'MKTRF'})

fdata = fdata[pd.to_numeric(fdata['date'], errors='coerce').notna()]


fdata['date'] = fdata['date'].astype(str)
fdata = fdata[fdata['date'].str.len() == 6]
fdata['date'] = fdata['date'].astype(int)

fdata = fdata[(fdata['date'] >= 196307) & (fdata['date'] <= 201312)]

vars_to_use = ['MKTRF', 'SMB', 'HML', 'RMW', 'CMA']
fdata[vars_to_use] = fdata[vars_to_use].apply(pd.to_numeric, errors='coerce')

n = len(fdata)       

panel_A = pd.DataFrame({
    'MKTRF': [
        fdata['MKTRF'].mean(),
        fdata['MKTRF'].std(),
        fdata['MKTRF'].mean() / (fdata['MKTRF'].std() / np.sqrt(n))
    ],
    'SMB': [
        fdata['SMB'].mean(),
        fdata['SMB'].std(),
        fdata['SMB'].mean() / (fdata['SMB'].std() / np.sqrt(n))
    ],
    'HML': [
        fdata['HML'].mean(),
        fdata['HML'].std(),
        fdata['HML'].mean() / (fdata['HML'].std() / np.sqrt(n))
    ],
    'RMW': [
        fdata['RMW'].mean(),
        fdata['RMW'].std(),
        fdata['RMW'].mean() / (fdata['RMW'].std() / np.sqrt(n))
    ],
    'CMA': [
        fdata['CMA'].mean(),
        fdata['CMA'].std(),
        fdata['CMA'].mean() / (fdata['CMA'].std() / np.sqrt(n))
    ]
}, index=['Mean', 'Std dev', 't-Statistic']).round(2)

panel_A
# Out:
#              MKTRF   SMB   HML   RMW   CMA
# Mean          0.50  0.28  0.38  0.26  0.33
# Std dev       4.48  3.04  2.79  2.25  2.00
# t-Statistic   2.75  2.26  3.38  2.89  4.01

# %% [markdown]
# <h2 style="font-family: Garamond; font-weight: bold; font-size: 20px; margin-bottom: 0.4em;">
# Original Table from Fama & French (2015 Paper)
# </h2>
#
# *Table 4. Summary statistics for monthly factor percent returns; July 1963–December 2013, 606 months.*
#
# ---
#
# ### Panel A: Averages, standard deviations, and t-statistics for monthly returns
# **2x3 Factors**
#
# | Statistic    | RMRF | SMB | HML | RMW | CMA |
# |:-------------|:-----|:----|:----|:----|:----|
# | Mean         | 0.50 | 0.29 | 0.37 | 0.25 | 0.33 |
# | Std. Dev.    | 4.49 | 3.07 | 2.88 | 2.14 | 2.01 |
# | t-Statistic  | 2.74 | 2.31 | 3.20 | 2.92 | 4.07 |

# %% [markdown]
# #### Correlation plot

# %%
import seaborn as sns
import matplotlib.pyplot as plt
cols = ['MKTRF', 'SMB', 'HML', 'RMW', 'CMA']
fdata_corr = fdata[cols].corr()

fdata_corr = fdata[cols].corr()
print(fdata_corr.round(2))

sns.heatmap(
    fdata_corr,
    vmin=-1, vmax=1,
    annot=True, fmt='.2f',
    cmap='coolwarm'
)
plt.title('Correlation Plot – 2×3 Factors (1963–2013)')
plt.show()
# Out:
#        MKTRF   SMB   HML   RMW   CMA
# MKTRF   1.00  0.27 -0.27 -0.23 -0.39
# SMB     0.27  1.00 -0.08 -0.34 -0.12
# HML    -0.27 -0.08  1.00  0.07  0.70
# RMW    -0.23 -0.34  0.07  1.00 -0.05
# CMA    -0.39 -0.12  0.70 -0.05  1.00

# %% [markdown]
# <h2 style="font-family: Garamond; font-weight: bold; font-size: 20px; margin-bottom: 0.4em;">
# Original Table from Fama & French (2015 Paper)
# </h2>
#
# *Table 4. Summary statistics for monthly factor percent returns; July 1963–December 2013, 606 months.*
#
# ---
#
# ### Panel C: Correlations between different factors
# **2 × 3 Factors**
#
# |        | RMRF | SMB  | HML  | RMW  | CMA  |
# |:-------|:-----|:-----|:-----|:-----|:-----|
# | RMRF   | 1.00 | 0.28 | -0.30 | -0.21 | -0.39 |
# | SMB    | 0.28 | 1.00 | -0.11 | -0.36 | -0.11 |
# | HML    | -0.30 | -0.11 | 1.00 | 0.08 | 0.70 |
# | RMW    | -0.21 | -0.36 | 0.08 | 1.00 | -0.11 |
# | CMA    | -0.39 | -0.11 | 0.70 | -0.11 | 1.00 |

# %% [markdown]
# <h2 style="font-family: Garamond; font-weight: bold; font-size: 20px; margin-bottom: 0.4em;">(c) - Y Side Summary Statistics (discrepancies)</h2>
#
# ---
#
# ### Overview
# This section compares our constructed portfolio return statistics against those reported in Fama and French (2015) for the same sample window, July 1963 through December 2013 with 606 monthly observations.
#
# All comparisons below refer exclusively to differences in reported means and implied cross sectional distributions of average excess returns.
#
# ---
#
# ### 1. 25-Portfolios: Size × B/M, Size × OP, Size × Investment
#
# #### Panel A: Size × Book-to-Market
#
# Our mean excess returns closely track those reported in the original paper. Across most cells the differences are within approximately 0.01 to 0.05 percentage points. The overall cross sectional shape is preserved, with higher returns concentrated in small and high B/M portfolios and lower returns among big and low B/M portfolios.
#
# The largest deviations appear in Big size portfolios, particularly in mid to high B/M categories. For example, Big portfolios in the third and fourth B/M columns show differences of around 0.05 to 0.06 relative to the original. While still small in magnitude, these are the most visible within this panel.
#
# The reported range of mean excess returns in our results is 0.2681 to 1.1138, which closely mirrors the original distribution. The dispersion and ranking of returns across the grid remain highly consistent.
#
# <span style="color:#122DAC; font-weight:bold;">Overall assessment:</span> Excellent replication with only minor numeric drift in Big portfolios.
#
# ---
#
# #### Panel B: Size × Operating Profitability
#
# Our values again remain very close to the original, with cell level deviations generally below 0.05. The majority of differences occur among Big portfolios, where our returns are modestly lower in both low and high profitability cells.
#
# For instance, Big low profitability and Big high profitability portfolios show differences around 0.03 to 0.04. Middle size categories also exhibit small deviations but remain tightly aligned across all columns.
#
# The range of our reported returns spans 0.3469 to 0.9919 which is nearly identical to the original dispersion.
#
# <span style="color:#122DAC; font-weight:bold;">Overall assessment:</span> Strong agreement with small downward shifts concentrated in Big portfolios.
#
# ---
#
# #### Panel C: Size × Investment
#
# This panel presents the closest match of all three 25-portfolio constructions. Most cells are either identical or differ by at most 0.01 to 0.02. The Small portfolios match almost perfectly across all Investment levels.
#
# The maximum and minimum values nearly coincide with the original table, and the overall distribution appears indistinguishable at a practical level.
#
# <span style="color:#122DAC; font-weight:bold;">Overall assessment:</span> Near-perfect replication with negligible discrepancies.
#
# ---
#
# ### 2. 32-Portfolios: 2 × 4 × 4 Three-Way Sorts
#
# This set exhibits noticeably greater variation compared to the 25-portfolio results. While broad cross sectional patterns remain intact, numeric differences become more pronounced as portfolio dimensionality increases.
#
# #### Panel A: Size × B/M × OP
#
# Small portfolios show good alignment with differences primarily within 0.02 to 0.06. Minor understatements appear in the lowest OP and highest B/M combinations but remain modest.
#
# Big portfolios show larger deviations. Several cells differ by 0.05 to 0.10. Particularly visible are portfolios combining Low OP with Low B/M and High OP with High B/M. The upper bound of the Big portfolio returns is slightly lower in our version, suggesting a compressed range.
#
# <span style="color:#122DAC; font-weight:bold;">Overall assessment:</span> Acceptable replication for Small portfolios, with more noticeable compression in Big portfolios.
#
# ---
#
# #### Panel B: Size × B/M × Investment
#
# Small portfolios continue to track the original well, though modest understatements occur in higher B/M buckets. Differences typically range from 0.02 to 0.07.
#
# The Big portfolios display slightly larger variation. For instance, Low Investment and high B/M combinations are consistently lower in our results by roughly 0.06 to 0.08. Nevertheless, the ranking of portfolios remains aligned and no sign reversals occur.
#
# <span style="color:#122DAC; font-weight:bold;">Overall assessment:</span> Good structural alignment with small compression in the upper tail of Big portfolios.
#
# ---
#
# #### Panel C: Size × OP × Investment
#
# This is where the most substantial discrepancies appear.
#
# Small portfolios are systematically lower across nearly every cell when compared to the original. Differences frequently exceed 0.10 and in some cases approach 0.25. The highest return portfolios in the original do not achieve the same magnitudes in our version, resulting in a clearly reduced upper bound.
#
# Big portfolios show even more pronounced compression. Numerous cells are lower by 0.20 to 0.35 relative to the published values. The entire Big portfolio grid exhibits a downward shift, especially for combinations involving low Investment and high Operating Profitability. The minimum values are slightly more negative than the original, while the maximum values are considerably lower.
#
# <span style="color:#C1121F; font-weight:bold;">Overall assessment:</span> This panel shows the largest and most systematic deviation in our replication, with compressed dispersion and consistently lower average returns.
#
# ---
#
# <h2 style="font-family: Garamond; font-weight: bold; font-size: 20px; margin-bottom: 0.4em;">
# (c) - X Side Summary Statistics (Discrepancies)
# </h2>
#
# ### Factor Means, Volatility, and t-Statistics
#
# Our factor summary statistics replicate the original Fama and French values very closely, with only minor numerical drift.
#
# **Means**
# All five factor means align almost exactly with the original table. The maximum deviation is 0.01. SMB is marginally lower in our results, while HML and RMW are slightly higher. These differences do not change factor ordering or economic scale.
#
# **Standard Deviations**
# Volatility levels are also tightly matched. The largest deviation appears for HML, where our standard deviation is 2.79 compared to the original 2.88. RMW is slightly more volatile in our data, while the remaining factors differ by 0.03 or less.
#
# **t-Statistics**
# t-statistics remain highly consistent. The largest difference is observed for HML, where our value of 3.38 exceeds the original 3.20. All other factors differ by less than 0.06, preserving both magnitude and inference regarding statistical significance.
#
# Overall, the factor distribution in our data mirrors the original with high precision and no meaningful distortion.
#
# ---
#
# ### Correlation Plot of Factors
#
# The correlation structure across factors is broadly preserved, with nearly identical signs and relative magnitudes.
#
# Most pairwise correlations fall within 0.02–0.03 of the published values. The most noticeable difference occurs between RMW and CMA, where our correlation of -0.05 is less negative than the original -0.11. Despite this, the qualitative relationship remains consistent.
#
# The strongest positive association remains between HML and CMA at 0.70 in both datasets, while MKTRF retains its expected negative relationship with CMA and HML.
#
# Overall, the correlation matrix maintains the same structural pattern as the original, with only small numerical softening in a few off-diagonal entries.
#
# ---
#
# ### Sample Description Summary
#
# Our Y-side summary statistics demonstrate strong overall consistency with Fama and French (2015), particularly for simpler portfolio constructions such as the 25 Size × Investment and 25 Size × B/M portfolios. In these cases, both the magnitude and distribution of average excess returns align closely with the published results, preserving the same cross-sectional ordering and economic interpretation.
#
# The largest deviations appear in the most granular three-way sorts, specifically those based on Size, Operating Profitability, and Investment. In these portfolios, our results are systematically lower and less dispersed than those reported in the original study. This compression is most visible among Big portfolios and in combinations involving low Investment and high Operating Profitability, where mean differences are noticeably larger than in the simpler sorts.
#
# Although these differences do not alter the qualitative structure of the results, they suggest that the replication environment is not perfectly identical to that of the original publication. One plausible contributor is the evolution of the data available through Kenneth French’s Data Library. The datasets currently distributed in 2025 may not be identical to the versions used by Fama and French in their 2014 research paper. Even subtle upstream revisions, such as changes in CRSP corrections, firm classifications, or updated handling of delistings and corporate actions, can propagate into portfolio formation and slightly shift average returns, particularly in more finely sorted portfolios.
#
# Additional sources of divergence may stem from small implementation differences, including portfolio construction timing, RF treatment, rounding conventions, or the precise filtering of monthly observations. These factors tend to exert minimal influence on broad portfolio groups but become more visible when returns are broken down into highly specific cells as in the 2 × 4 × 4 sorts.
#
# Overall, the observed discrepancies appear quantitative rather than structural. The patterns, monotonic relationships, and economic interpretation of the portfolios remain consistent with the original framework, reinforcing that our replication successfully captures the core empirical behavior of the Fama-French five-factor model while naturally reflecting the realities of modern data availability and updated source series.

# %% [markdown]
# <h2 style="font-family: Garamond; font-weight: bold; font-size: 20px; margin-bottom: 0.3em;">
# (d) Variable Construction
# </h2>
#
# Although this replication project relies on factor and portfolio return series downloaded directly from Kenneth R. French’s Data Library, where all factor construction and portfolio sorting procedures are already implemented, it is still important to document the underlying methodology used in the original Fama & French (2015) paper. Doing so clarifies the economic meaning of the variables and ensures transparency regarding how these series would be constructed if raw firm level data were used.
#
# This framework describes how the Fama French factors are constructed when using 2 × 3 independent sorts on firm characteristics. Stocks are assigned to portfolios based on Size and one secondary characteristic, either Book to Market (B/M), Operating Profitability (OP), or Investment (Inv).
#
# ---
#
# ### Sort Structure
#
# Firms are sorted as follows:
#
# Primary sort
# Size, using the NYSE median market capitalization
# This divides firms into Small (S) and Big (B)
#
# Secondary sort
# 30th and 70th NYSE percentiles of the relevant characteristic:
#
# Book to Market → High (H), Neutral (N), Low (L)
# Operating Profitability → Robust (R), Neutral (N), Weak (W)
# Investment → Conservative (C), Neutral (N), Aggressive (A)
#
# This produces 6 portfolios per characteristic combination, or 2 × 3 portfolios.
#
# ---
#
# ### Construction of SMB
#
# Three versions of SMB are created from the different characteristic sorts:
#
# SMB<sub>B/M</sub> = (SH + SN + SL)/3 − (BH + BN + BL)/3
# SMB<sub>OP</sub> = (SR + SN + SW)/3 − (BR + BN + BW)/3
# SMB<sub>Inv</sub> = (SC + SN + SA)/3 − (BC + BN + BA)/3
#
# The final SMB factor is the average of these three components:
#
# SMB = (SMB<sub>B/M</sub> + SMB<sub>OP</sub> + SMB<sub>Inv</sub>) / 3
#
# ---
#
# ### Construction of HML
#
# HML captures the return spread between high and low book to market firms:
#
# HML = (SH + BH)/2 − (SL + BL)/2
# HML = [(SH − SL) + (BH − BL)] / 2
#
# ---
#
# ### Construction of RMW
#
# RMW measures the profitability premium between firms with robust and weak operating profitability:
#
# RMW = (SR + BR)/2 − (SW + BW)/2
# RMW = [(SR − SW) + (BR − BW)] / 2
#
# ---
#
# ### Construction of CMA
#
# CMA captures the investment premium between conservative and aggressive firms:
#
# CMA = (SC + BC)/2 − (SA + BA)/2
# CMA = [(SC − SA) + (BC − BA)] / 2
#
# ---
#
# ### Portfolio Label Key
#
# S = Small, B = Big
# H = High B/M, N = Neutral, L = Low B/M
# R = Robust profitability, W = Weak profitability
# C = Conservative investment, A = Aggressive investment
#
# ---
#
# ### Conceptual Difference Between 5 × 5 and 2 × 4 × 4 Portfolio Sorts
#
# The dependent variables in the empirical tests are portfolio excess returns, and these portfolios are constructed using different sorting schemes depending on the purpose of the test.
#
# The 5 × 5 sorts represent the core test portfolios. Firms are sorted into five size groups and five characteristic groups, producing 25 portfolios. Conceptually, this can be thought of as a grid where each cell represents firms that share similar size and similar levels of a given characteristic such as B/M, profitability, or investment. These portfolios form the primary set used to evaluate how well the factor model explains returns.
#
# The 2 × 4 × 4 sorts follow a different logic. Firms are first split into Small and Big groups, and then each of those groups is independently sorted into four groups based on two characteristics. This results in 32 portfolios. These sorts are used primarily as robustness tests. The goal is not to replace the main 5 × 5 structure but to examine whether the factor model continues to perform well when size is controlled more sharply and when interactions between characteristics such as value, profitability, and investment are observed more directly.
#
# In this sense, the 2 × 4 × 4 portfolios allow the authors to explore whether performance differences across portfolios are truly driven by the intended risk factors or whether they are influenced by overlapping or confounding firm characteristics. These tests provide additional evidence about the stability and reliability of the model’s explanatory power.
#
# ---
#
# This construction procedure ensures that each factor isolates a specific dimension of firm characteristic risk while maintaining consistency across sorting schemes. In this replication, all factors and portfolio returns were sourced directly from the Kenneth French Data Library in their pre constructed form. However, the conceptual foundation and construction logic follow exactly the procedures described in Fama & French (2015).

# %%
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle

plt.rcParams["font.family"] = "Garamond"

def draw_grid(ax, n_rows, n_cols, row_label, col_label,
              row_names=None, col_names=None, title=""):
    ax.set_title(title, fontsize=14, pad=10)
    ax.set_xlim(0, n_cols)
    ax.set_ylim(0, n_rows)
    ax.set_aspect("equal")

    for i in range(n_rows):
        for j in range(n_cols):
            rect = Rectangle((j, i), 1, 1,
                             fill=False, linewidth=1)
            ax.add_patch(rect)

    ax.set_xticks([k + 0.5 for k in range(n_cols)])
    ax.set_yticks([k + 0.5 for k in range(n_rows)])
    ax.set_xticklabels(col_names if col_names else ["" for _ in range(n_cols)])
    ax.set_yticklabels(row_names if row_names else ["" for _ in range(n_rows)])

    ax.set_xlabel(col_label, fontsize=12)
    ax.set_ylabel(row_label, fontsize=12)

    ax.tick_params(axis='both', length=0)
    for spine in ax.spines.values():
        spine.set_visible(False)


fig, ax = plt.subplots(figsize=(5, 5))

row_names_5 = ["Small Q1", "Q2", "Q3", "Q4", "Big Q5"]
col_names_5 = ["Q1", "Q2", "Q3", "Q4", "Q5"]

draw_grid(ax,
          n_rows=5,
          n_cols=5,
          row_label="Size ↓",
          col_label="Characteristic Quintiles →",
          row_names=row_names_5,
          col_names=col_names_5,
          title="25 Portfolios: Size × Characteristic (5×5)")

plt.tight_layout()
plt.show()


fig, axes = plt.subplots(1, 2, figsize=(9, 4), sharey=True)

col_names_4 = ["Q1", "Q2", "Q3", "Q4"]
row_names_4 = ["Q1", "Q2", "Q3", "Q4"]

draw_grid(axes[0],
          n_rows=4,
          n_cols=4,
          row_label="Characteristic 2 ↓",
          col_label="Characteristic 1 →",
          row_names=row_names_4,
          col_names=col_names_4,
          title="Small Firms (4×4)")

draw_grid(axes[1],
          n_rows=4,
          n_cols=4,
          row_label="",
          col_label="Characteristic 1 →",
          row_names=row_names_4,
          col_names=col_names_4,
          title="Big Firms (4×4)")

fig.suptitle("32 Portfolios: 2×4×4 Sort (Small vs Big)", fontsize=16, y=1.05)
plt.tight_layout()
plt.show()

# %% [markdown]
# <h2 style="font-family: Garamond; font-weight: bold; font-size: 20px; margin-bottom: 0.3em;">
# (e) Missing Data:
# </h2>
#
# Missing data is not a concern for the primary time-series dataset used in this analysis. The descriptive statistics for our final sample (N = 606) show identical observation counts across all variables, indicating that no missing values (NaN) remain in the factor return series after preprocessing.
#
# This is consistent with the methodology of the original paper. Fama and French (2015) do not impute missing data; instead, they address it through sample construction. Their portfolios are formed using “all NYSE, AMEX, and NASDAQ stocks on both CRSP and Compustat” that meet strict data availability requirements for variables such as Size and Book-to-Market. Firms lacking the required accounting or market data are excluded prior to portfolio formation, ensuring that the resulting factor returns are based only on complete observations.
#
# Two practical considerations of “missing data” arose during replication:
#
# **Exclusion of Extreme Robustness Sorts**
#    The most granular portfolio sorts (e.g., 2×2 and 2×2×2×2 dimensions), which serve as extreme robustness checks in the original study, were not included due to time constraints. Per guidance from Professor Rojas, these robustness extensions were not required for this replication and their exclusion does not affect the core validation of the five-factor model.
#
#
# In summary, while no missing observations exist within the finalized dataset itself, non-essential robustness portfolios might have influenced replication of the original empirical design.

# %% [markdown]
# ---

# %% [markdown]
# <h1 style="font-family: Garamond; font-weight: bold; font-size: 18px; margin-bottom: 0.3em;">
# 3. Replication Analysis
# </h1>

# %% [markdown]
# <h2 style="font-family: Garamond; font-weight: bold; font-size: 18px; margin-bottom: 0.3em;">
# (a) Model Specification:
# </h2>

# %% [markdown]
# We estimate the Fama–French Five-Factor Model, which explains the excess return of a portfolio using five systematic risk factors. The regression equation is:
#
# $$
# R_{it} - R_{ft}
# = \alpha_i
# + b_i \, (R_{Mt} - R_{ft})
# + s_i \, SMB_t
# + h_i \, HML_t
# + r_i \, RMW_t
# + c_i \, CMA_t
# + \varepsilon_{it}.
# $$
#
#
# where:
#
# - **$R_{it} - R_{ft}$**
#   Portfolio *i*’s **excess return** at time *t*.
#   This is the dependent variable of the regression.
#
# - **$\alpha$**
#   The portfolio’s **abnormal return** (intercept).
#   If the model prices the portfolio correctly, $\alpha_i$ should be statistically indistinguishable from zero.
#
# - **$R_{Mt} - R_{ft}$** (MKT-RF)
#   The **market excess return**.
#   Captures the portfolio’s exposure to overall market risk.
#
# - **$SMB_t$**
#   “Small Minus Big.”
#   The **size factor**, measuring the excess return of small firms over large firms.
#
# - **$HML_t$**
#   “High Minus Low.”
#   The **value factor**, measuring the return spread between high book-to-market (value) and low book-to-market (growth) firms.
#
# - **$RMW_t$**
#   “Robust Minus Weak.”
#   The **profitability factor**, capturing the return difference between firms with robust vs. weak operating profitability.
#
# - **$CMA_t$**
#   “Conservative Minus Aggressive.”
#   The **investment factor**, measuring the return spread between firms that invest conservatively and those that invest aggressively.
#
# - **$\varepsilon_{it}$**
#   Regression error term.
#
#  **Coefficients**
# - $b_i$: loading on the market factor
# - $s_i$: loading on the size factor
# - $h_i$: loading on the value factor
# - $r_i$: loading on the profitability factor
# - $c_i$: loading on the investment factor
#
#
# These coefficients measure how sensitively the portfolio’s excess return responds to movements in each factor. The model is estimated using monthly data and Newey–West (HAC) standard errors to correct for potential autocorrelation and heteroskedasticity.

# %% [markdown]
# **Loading the Model:**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
import statsmodels.formula.api as smf
from scipy import stats

factors = pd.read_csv('data/five_factor_model/factors/5f_data.csv', skiprows=4)
factors = factors[pd.to_numeric(factors['Unnamed: 0'], errors='coerce').notna()]
factors = factors.rename(columns={'Unnamed: 0': 'date', 'Mkt-RF': 'MKTRF'})
factors = factors[['date', 'MKTRF', 'SMB', 'HML', 'RMW', 'CMA', 'RF']]
factors.iloc[:, 1:] = factors.iloc[:, 1:].apply(pd.to_numeric, errors='coerce')

portSBM = pd.read_csv('data/five_factor_model/portfolios/25_Portfolios_5x5_on_size_BM.csv', skiprows=15)
portSBM = portSBM.rename(columns={'Unnamed: 0': 'date'})
portSBM = portSBM[pd.to_numeric(portSBM['date'], errors='coerce').notna()]
portSBM = portSBM[:-1]

portSBM.iloc[:, 1:] = portSBM.iloc[:, 1:].apply(pd.to_numeric, errors='coerce')

factors = factors.drop_duplicates(subset='date')
portSBM = portSBM.drop_duplicates(subset='date')

dataSBM = pd.merge(portSBM, factors, on='date', how='inner')
dataSBM['date']
cutoff_row = dataSBM.index[dataSBM['date'] > '201312'][0]
dataSBM = dataSBM.iloc[:cutoff_row]

# %% [markdown]
# <h2 style="font-family: Garamond; font-weight: bold; font-size: 18px; margin-bottom: 0.3em;">
# (b) Estimation Results:
# </h2>

# %% [markdown]
# **Three Factor Book-to-Market Model** <br>
# - Run Section 3 Appendix First

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
import statsmodels.formula.api as smf
from scipy import stats

tfactors = pd.read_csv('data/three_factor_model/factors/3f_data.csv', skiprows=4)
tfactors = tfactors[pd.to_numeric(tfactors['Unnamed: 0'], errors='coerce').notna()]
tfactors = tfactors.rename(columns={'Unnamed: 0': 'date', 'Mkt-RF': 'MKTRF'})
tfactors = tfactors[['date', 'MKTRF', 'SMB', 'HML', 'RF']]
tfactors.iloc[:, 1:] = tfactors.iloc[:, 1:].apply(pd.to_numeric, errors='coerce')
portSBM = pd.read_csv('data/five_factor_model/portfolios/25_Portfolios_5x5_on_size_BM.csv', skiprows=15)
portSBM = portSBM.rename(columns={'Unnamed: 0': 'date'})
portSBM = portSBM[pd.to_numeric(portSBM['date'], errors='coerce').notna()]
portSBM = portSBM[:-1]
portSBM.iloc[:, 1:] = portSBM.iloc[:, 1:].apply(pd.to_numeric, errors='coerce')

tfactors = tfactors.drop_duplicates(subset='date')
portSBM = portSBM.drop_duplicates(subset='date')

data3 = pd.merge(portSBM, tfactors, on='date', how='inner')
cutoff_row = data3.index[data3['date'] > '201312'][0]
data3 = data3.iloc[:cutoff_row]

# %%
data3.columns = data3.columns.str.strip()

factor_cols = ['MKTRF', 'SMB', 'HML', 'RF']

data3[factor_cols] = data3[factor_cols].apply(pd.to_numeric, errors='coerce')
X = data3[['MKTRF', 'SMB', 'HML']]
X = sm.add_constant(X)  

portfolio_cols = [c for c in data3.columns if c not in factor_cols + ['date']]

results = []

rf = data3['RF']

for port_name in portfolio_cols:
    y = pd.to_numeric(data3[port_name], errors='coerce') - rf

    reg = sm.OLS(y, X, missing='drop').fit(
        cov_type='HAC', cov_kwds={'maxlags': 12}
    )

    results.append({
        'Portfolio': port_name,
        'Alpha': reg.params['const'],
        't(Alpha)': reg.tvalues['const'],
        'b_MKT': reg.params['MKTRF'],
        't(MKT)': reg.tvalues['MKTRF'],
        'b_SMB': reg.params['SMB'],
        't(SMB)': reg.tvalues['SMB'],
        'b_HML': reg.params['HML'],
        't(HML)': reg.tvalues['HML'],
        'R2': reg.rsquared
    })

results3 = pd.DataFrame(results).set_index('Portfolio')
results3
# Out:
#                Alpha  t(Alpha)     b_MKT     t(MKT)     b_SMB     t(SMB)  \
# Portfolio
# SMALL LoBM -0.741905 -4.779566  1.275119  14.132233  1.462458   7.251228
# ME1 BM2    -0.470119 -3.789396  1.075688  43.863750  1.552757   8.568266
# ME1 BM3    -0.144915 -2.287044  1.054558  26.428617  1.243709  24.098374
# ME1 BM4     0.076479  1.231380  0.947758  43.958603  1.248086  11.631564
# SMALL HiBM  0.084650  1.424591  0.987474  40.394389  1.293517  17.803493
# ME2 BM1    -0.230767 -3.505146  1.087470  38.115335  1.140145  15.946026
# ME2 BM2    -0.002461 -0.038344  1.022330  60.358989  1.005546  13.919419
# ME2 BM3     0.021917  0.403924  0.985278  39.749415  0.823746  10.176094
# ME2 BM4     0.024851  0.518920  0.971764  53.954338  0.820903  11.998791
# ME2 BM5     0.034042  0.635685  1.063203  49.759931  0.924641  20.543271
# ME3 BM1    -0.110176 -2.161154  1.131326  59.297099  0.807417  17.753192
# ME3 BM2     0.115658  2.105436  1.020811  55.608420  0.552828  15.070120
# ...

# %% [markdown]
# **Five Factor Book-to-Market Model**

# %%
factors = pd.read_csv('data/five_factor_model/factors/5f_data.csv', skiprows=4)
factors = factors[pd.to_numeric(factors['Unnamed: 0'], errors='coerce').notna()]
factors = factors.rename(columns={'Unnamed: 0': 'date', 'Mkt-RF': 'MKTRF'})
factors = factors[['date', 'MKTRF', 'SMB', 'HML', 'RMW', 'CMA', 'RF']]
factors.iloc[:, 1:] = factors.iloc[:, 1:].apply(pd.to_numeric, errors='coerce')

portSBM = pd.read_csv('data/five_factor_model/portfolios/25_Portfolios_5x5_on_size_BM.csv', skiprows=15)
portSBM = portSBM.rename(columns={'Unnamed: 0': 'date'})
portSBM = portSBM[pd.to_numeric(portSBM['date'], errors='coerce').notna()]
portSBM = portSBM[:-1]

portSBM.iloc[:, 1:] = portSBM.iloc[:, 1:].apply(pd.to_numeric, errors='coerce')

factors = factors.drop_duplicates(subset='date')
portSBM = portSBM.drop_duplicates(subset='date')

dataSBM = pd.merge(portSBM, factors, on='date', how='inner')
dataSBM['date']
cutoff_row = dataSBM.index[dataSBM['date'] > '201312'][0]
dataSBM = dataSBM.iloc[:cutoff_row]

# %%
dataSBM.columns = dataSBM.columns.str.strip()

factor_cols = ['MKTRF', 'SMB', 'HML', 'RMW', 'CMA', 'RF']

dataSBM[factor_cols] = dataSBM[factor_cols].apply(pd.to_numeric, errors='coerce')
X = dataSBM[['MKTRF', 'SMB', 'HML', 'RMW', 'CMA']]
X = sm.add_constant(X)

portfolio_cols = [c for c in dataSBM.columns if c not in factor_cols + ['date']]

results = []

rf = dataSBM['RF']

for port_name in portfolio_cols:
    y = pd.to_numeric(dataSBM[port_name], errors='coerce') - rf

    reg = sm.OLS(y, X, missing='drop').fit(
        cov_type='HAC', cov_kwds={'maxlags': 12}
    )

    results.append({
        'Portfolio': port_name,
        'Alpha': reg.params['const'],
        't(Alpha)': reg.tvalues['const'],
        'b_MKT': reg.params['MKTRF'],
        't(MKT)': reg.tvalues['MKTRF'],
        'b_SMB': reg.params['SMB'],
        't(SMB)': reg.tvalues['SMB'],
        'b_HML': reg.params['HML'],
        't(HML)': reg.tvalues['HML'],
        'b_RMW': reg.params['RMW'],
        't(RMW)': reg.tvalues['RMW'],
        'b_CMA': reg.params['CMA'],
        't(CMA)': reg.tvalues['CMA'],
        'R2': reg.rsquared
    })

resultsSBM = pd.DataFrame(results).set_index('Portfolio')
resultsSBM
# Out:
#                Alpha  t(Alpha)     b_MKT     t(MKT)     b_SMB     t(SMB)  \
# Portfolio
# SMALL LoBM -0.276061 -3.253392  1.052896  45.860957  1.244305  25.704363
# ME1 BM2     0.153988  1.559768  0.929513  40.937171  1.231316  25.722394
# ME1 BM3    -0.020663 -0.375115  0.937119  68.617076  1.073297  38.888013
# ME1 BM4     0.179040  2.623272  0.887755  47.196876  1.062326  39.793398
# SMALL HiBM  0.103783  1.596958  0.970478  44.652659  1.070861  32.499493
# ME2 BM1    -0.069492 -1.165435  1.096112  60.205065  0.972321  29.939089
# ME2 BM2    -0.049703 -0.979706  1.021679  71.017489  0.949824  28.959790
# ME2 BM3    -0.014350 -0.190036  0.979892  42.213016  0.813365  28.046249
# ME2 BM4     0.008849  0.173090  0.968575  63.542817  0.734015  33.341206
# ME2 BM5    -0.009350 -0.158682  1.076203  81.190348  0.880749  34.104028
# ME3 BM1     0.028081  0.487859  1.073643  61.060959  0.693875  25.733591
# ME3 BM2    -0.003465 -0.052053  1.037531  53.804631  0.641697  27.294383
# ...

# %% [markdown]
# **Three Factor Means, Absolute Alphas, Betas, and R-Squared**

# %%
summary_results3 = pd.DataFrame({
    'Avg |Alpha|': [results3['Alpha'].abs().mean()],
    'Avg |t(Alpha)|': [results3['t(Alpha)'].abs().mean()],
    'Avg b_MKT': [results3['b_MKT'].mean()],
    'Avg b_SMB': [results3['b_SMB'].mean()],
    'Avg b_HML': [results3['b_HML'].mean()],
    'Avg R2': [results3['R2'].mean()]
}, index=['Three Factor'])

summary_results3
# Out:
#               Avg |Alpha|  Avg |t(Alpha)|  Avg b_MKT  Avg b_SMB  Avg b_HML  \
# Three Factor     0.122391        1.495751   1.050253   0.587007   0.373359
#
#                 Avg R2
# Three Factor  0.908303

# %% [markdown]
# **Five Factor Means, Absolute Alphas, and Betas, and R-Squared**

# %%
factor_cols = ['MKTRF', 'SMB', 'HML', 'RMW', 'CMA', 'RF']

def avg_excess_return(df):
    
    rf = pd.to_numeric(df['RF'], errors='coerce')
    
    port_cols = [c for c in df.columns if c not in factor_cols + ['date']]
    
    ports = df[port_cols].apply(pd.to_numeric, errors='coerce')
    excess = ports.sub(rf, axis=0)        
    
    return excess.mean().mean()

# %%
def safe_mean(df, col):
    return df[col].mean() if col in df.columns else np.nan

def avg_excess(df):
    rf = pd.to_numeric(df['RF'], errors='coerce')
    port_cols = [c for c in df.columns if c not in ['MKTRF','SMB','HML','RMW','CMA','RF','date']]
    ports = df[port_cols].apply(pd.to_numeric, errors='coerce')
    excess = ports.sub(rf, axis=0)
    return excess.mean().mean()

ff_stats = pd.DataFrame({

    'Avg |Alpha|': [
        resultsSBM['Alpha'].abs().mean(),
        resultsSIN['Alpha'].abs().mean(),
        resultsSOP['Alpha'].abs().mean(),
        resultsBMIN['Alpha'].abs().mean(),
        resultsBMOP['Alpha'].abs().mean(),
        resultsOPIN['Alpha'].abs().mean()
    ],
    'Avg |t(Alpha)|': [
        resultsSBM['t(Alpha)'].abs().mean(),
        resultsSIN['t(Alpha)'].abs().mean(),
        resultsSOP['t(Alpha)'].abs().mean(),
        resultsBMIN['t(Alpha)'].abs().mean(),
        resultsBMOP['t(Alpha)'].abs().mean(),
        resultsOPIN['t(Alpha)'].abs().mean()
    ],
    'Avg b_MKT': [
        safe_mean(resultsSBM, 'b_MKT'),
        safe_mean(resultsSIN, 'b_MKT'),
        safe_mean(resultsSOP, 'b_MKT'),
        safe_mean(resultsBMIN, 'b_MKT'),
        safe_mean(resultsBMOP, 'b_MKT'),
        safe_mean(resultsOPIN, 'b_MKT')
    ],
    'Avg b_SMB': [
        safe_mean(resultsSBM, 'b_SMB'),
        safe_mean(resultsSIN, 'b_SMB'),
        safe_mean(resultsSOP, 'b_SMB'),
        safe_mean(resultsBMIN, 'b_SMB'),
        safe_mean(resultsBMOP, 'b_SMB'),
        safe_mean(resultsOPIN, 'b_SMB')
    ],
    'Avg b_HML': [
        safe_mean(resultsSBM, 'b_HML'),
        safe_mean(resultsSIN, 'b_HML'),
        safe_mean(resultsSOP, 'b_HML'),
        safe_mean(resultsBMIN, 'b_HML'),
        safe_mean(resultsBMOP, 'b_HML'),
        safe_mean(resultsOPIN, 'b_HML')
    ],
    'Avg b_RMW': [
        safe_mean(resultsSBM, 'b_RMW'),
        safe_mean(resultsSIN, 'b_RMW'),
        safe_mean(resultsSOP, 'b_RMW'),
        safe_mean(resultsBMIN, 'b_RMW'),
        safe_mean(resultsBMOP, 'b_RMW'),
        safe_mean(resultsOPIN, 'b_RMW')
    ],
    'Avg b_CMA': [
        safe_mean(resultsSBM, 'b_CMA'),
        safe_mean(resultsSIN, 'b_CMA'),
        safe_mean(resultsSOP, 'b_CMA'),
        safe_mean(resultsBMIN, 'b_CMA'),
        safe_mean(resultsBMOP, 'b_CMA'),
        safe_mean(resultsOPIN, 'b_CMA')
    ],
    'Avg R2': [
        safe_mean(resultsSBM, 'R2'),
        safe_mean(resultsSIN, 'R2'),
        safe_mean(resultsSOP, 'R2'),
        safe_mean(resultsBMIN, 'R2'),
        safe_mean(resultsBMOP, 'R2'),
        safe_mean(resultsOPIN, 'R2')
    ],

    'Avg Excess Return': [
        avg_excess(dataSBM),
        avg_excess(dataSIN),
        avg_excess(dataSOP),
        avg_excess(dataBMIN),
        avg_excess(dataBMOP),
        avg_excess(dataOPIN)
    ]
},
    index=[
        'Size-BM (25 SMB)',
        'Size-INV (25 SIN)',
        'Size-OP (25 SOP)',
        'ME-BM INV (32 BMIN)',
        'ME-BM OP (32 BMOP)',
        'ME-OP INV (32 OPIN)'
    ]
)

ff_stats['Alpha / Avg Excess'] = ff_stats['Avg |Alpha|'] / ff_stats['Avg Excess Return']

new_order = (['Avg Excess Return', 'Avg |Alpha|', 'Avg |t(Alpha)|', 'Alpha / Avg Excess'] +
             [col for col in ff_stats.columns if col not in 
              ['Avg Excess Return', 'Avg |Alpha|', 'Avg |t(Alpha)|', 'Alpha / Avg Excess']])

ff_stats = ff_stats[new_order]

ff_stats.loc['Overall Average'] = ff_stats.mean()

ff_stats
# Out:
#                      Avg Excess Return  Avg |Alpha|  Avg |t(Alpha)|  \
# Size-BM (25 SMB)              0.731210     0.093124        1.252031
# Size-INV (25 SIN)             0.736065     0.086367        1.328872
# Size-OP (25 SOP)              0.701515     0.065514        0.948407
# ME-BM INV (32 BMIN)           0.736596     0.099492        1.283886
# ME-BM OP (32 BMOP)            0.720147     0.116674        1.232668
# ME-OP INV (32 OPIN)           0.720147     0.116674        1.232668
# Overall Average               0.724280     0.096307        1.213089
#
#                      Alpha / Avg Excess  Avg b_MKT  Avg b_SMB  Avg b_HML  \
# Size-BM (25 SMB)               0.127355   1.023809   0.537513   0.206231
# Size-INV (25 SIN)              0.117336   1.018210   0.536705   0.083648
# Size-OP (25 SOP)               0.093389   1.025749   0.525228   0.113027
# ME-BM INV (32 BMIN)            0.135070   1.024315   0.429663   0.204201
# ...

# %% [markdown]
# **GRS Statistics**

# %%
import numpy as np
from scipy.stats import f
import statsmodels.api as sm

def grs_test(data, portfolio_cols, factor_cols=['MKTRF','SMB','HML','RMW','CMA'], rf_col='RF'):
   
    data = data.copy()
    data[factor_cols + [rf_col]] = data[factor_cols + [rf_col]].apply(pd.to_numeric, errors='coerce')
    data[portfolio_cols] = data[portfolio_cols].apply(pd.to_numeric, errors='coerce')

    
    data = data.dropna(subset=factor_cols + [rf_col])

    F = data[factor_cols].values
    T = F.shape[0]
    K = F.shape[1]

   
    X = sm.add_constant(F)  

    
    alphas = []
    resid_list = []

    for p in portfolio_cols:
        y = (data[p] - data[rf_col]).values    
        mask = ~np.isnan(y)
        y_ = y[mask]
        X_ = X[mask, :]

        res = sm.OLS(y_, X_).fit()
        alphas.append(res.params[0])      
        
        r_full = np.full(T, np.nan)
        r_full[mask] = res.resid
        resid_list.append(r_full)

    alphas = np.array(alphas)                 
    resid_mat = np.column_stack(resid_list)   

    valid_rows = ~np.isnan(resid_mat).any(axis=1)
    resid_mat = resid_mat[valid_rows, :]
    F_valid = F[valid_rows, :]

    T_eff = resid_mat.shape[0]
    N = len(portfolio_cols)

    Sigma = np.cov(resid_mat, rowvar=False)           
    Sf = np.cov(F_valid, rowvar=False)                
    f_bar = F_valid.mean(axis=0)                      

   
    eps = 1e-8
    Sigma_inv = np.linalg.inv(Sigma + eps * np.eye(N))
    Sf_inv = np.linalg.inv(Sf)

   
    num_prefactor = (T_eff - N - K) / N
    alpha_sig = alphas.T @ Sigma_inv @ alphas
    denom = 1.0 + f_bar.T @ Sf_inv @ f_bar

    GRS = num_prefactor * (alpha_sig / denom)

    df1 = N
    df2 = T_eff - N - K
    pval = 1 - f.cdf(GRS, df1, df2)

    return GRS, pval, df1, df2

# %%
portfolio_cols_SBM = [c for c in dataSBM.columns if c not in factor_cols + ['date']]

GRS_SBM, p_SBM, df1_SBM, df2_SBM = grs_test(
    dataSBM,
    portfolio_cols_SBM,
    factor_cols=['MKTRF','SMB','HML','RMW','CMA'],
    rf_col='RF'
)
factor_cols = ['MKTRF','SMB','HML','RMW','CMA','RF']
portfolio_cols_SIN = [c for c in dataSIN.columns if c not in factor_cols + ['date']]

GRS_SIN, p_SIN, df1_SIN, df2_SIN = grs_test(
    dataSIN,
    portfolio_cols_SIN,
    factor_cols=['MKTRF','SMB','HML','RMW','CMA'],
    rf_col='RF'
)
portfolio_cols_SOP = [c for c in dataSOP.columns if c not in factor_cols + ['date']]

GRS_SOP, p_SOP, df1_SOP, df2_SOP = grs_test(
    dataSOP,
    portfolio_cols_SOP,
    factor_cols=['MKTRF','SMB','HML','RMW','CMA'],
    rf_col='RF'
)
portfolio_cols_BMIN = [c for c in dataBMIN.columns if c not in factor_cols + ['date']]

GRS_BMIN, p_BMIN, df1_BMIN, df2_BMIN = grs_test(
    dataBMIN,
    portfolio_cols_BMIN,
    factor_cols=['MKTRF','SMB','HML','RMW','CMA'],
    rf_col='RF'
)
portfolio_cols_BMOP = [c for c in dataBMOP.columns if c not in factor_cols + ['date']]

GRS_BMOP, p_BMOP, df1_BMOP, df2_BMOP = grs_test(
    dataBMOP,
    portfolio_cols_BMOP,
    factor_cols=['MKTRF','SMB','HML','RMW','CMA'],
    rf_col='RF'
)
portfolio_cols_OPIN = [c for c in dataOPIN.columns if c not in factor_cols + ['date']]

GRS_OPIN, p_OPIN, df1_OPIN, df2_OPIN = grs_test(
    dataOPIN,
    portfolio_cols_OPIN,
    factor_cols=['MKTRF','SMB','HML','RMW','CMA'],
    rf_col='RF'
)
portfolio_cols_3 = [c for c in data3.columns if c not in factor_cols + ['date']]

GRS_3, p_3, df1_3, df2_3 = grs_test(
    data3,
    portfolio_cols_3,
    factor_cols=['MKTRF','SMB','HML'],
    rf_col='RF'
)

# %%
grs_df = pd.DataFrame({
    'GRS Statistic': [
        GRS_SBM, 
        GRS_SIN, 
        GRS_SOP, 
        GRS_BMIN, 
        GRS_BMOP, 
        GRS_OPIN,
        GRS_3
    ],
    'p-value': [
        p_SBM, 
        p_SIN, 
        p_SOP, 
        p_BMIN, 
        p_BMOP, 
        p_OPIN,
        p_3
    ],
    'df1': [
        df1_SBM, 
        df1_SIN, 
        df1_SOP, 
        df1_BMIN, 
        df1_BMOP, 
        df1_OPIN,
        df1_3
    ],
    'df2': [
        df2_SBM, 
        df2_SIN, 
        df2_SOP, 
        df2_BMIN, 
        df2_BMOP, 
        df2_OPIN,
        df2_3
    ]
},
    index=[
        'Size-BM (25 SMB)',
        'Size-INV (25 SIN)',
        'Size-OP (25 SOP)',
        'ME-BM INV (32 BMIN)',
        'ME-BM OP (32 BMOP)',
        'ME-OP INV (32 OPIN)',
        'Three Factor Size-BM (25 SMB)'
    ]
)
grs_df
# Out:
#                                GRS Statistic       p-value  df1   df2
# Size-BM (25 SMB)                    3.079949  1.073566e-06   25   576
# Size-INV (25 SIN)                   3.520010  3.192506e-08   25   576
# Size-OP (25 SOP)                    1.893334  5.784914e-03   25   576
# ME-BM INV (32 BMIN)                 2.177082  2.505183e-04   32   569
# ME-BM OP (32 BMOP)                  1.994770  1.119278e-03   32   569
# ME-OP INV (32 OPIN)                 1.994770  1.119278e-03   32   569
# Three Factor Size-BM (25 SMB)       3.154988  3.555238e-07   25  1022

# %% [markdown]
# **Note**: In order to maintain readability, the remainder of the regression tables and corresponding code were placed in the appendix. <br> This was approved and advised by Dr. Rojas.

# %% [markdown]
# <h2 style="font-family: Garamond; font-weight: bold; font-size: 18px; margin-bottom: 0.3em;">
# (c) Comparison with Original:
# </h2>

# %% [markdown]
# **Three-Factor Model** <br><br>
#  **a and t(a)**
#
# |       | Low a | 2 a | 3 a | 4 a | High a | Low t | 2 t | 3 t | 4 t | High t |
# |-------|--------|--------|--------|--------|----------|---------|---------|---------|---------|-----------|
# | Small | -0.74 | -0.47 | -0.14 | 0.07 | 0.08 | -4.78 | -3.79 | -2.29 | 1.23 | 1.42 |
# | 2     | -0.23 | -0.00 | 0.02 | 0.02 | 0.03 | -3.51 | -0.04 | 0.40 | 0.52 | 0.64 |
# | 3     | -0.12 | -0.02 | 0.08 | 0.06 | -0.04 | -2.16 | -0.16 | 1.31 | 1.12 | -0.66 |
# | 4     | 0.08 | 0.00 | -0.01 | 0.04 | -0.24 | 1.33 | 0.03 | -0.06 | 0.69 | -3.53 |
# | Big   | 0.08 | 0.00 | -0.01 | -0.24 | -0.20 | 1.96 | 0.06 | -0.10 | -3.53 | -1.59 |
#
# **Five-factor coefficients**
#
# **a and t(a)**
#
# |       | Low a | 2 a | 3 a | 4 a | High a | Low t | 2 t | 3 t | 4 t | High t |
# |-------|--------|--------|--------|--------|----------|--------|--------|--------|--------|----------|
# | Small | -0.28 | 0.15 | -0.02 | 0.18 | 0.10 | -3.25 | 1.56 | -0.38 | 2.62 | 1.57 |
# | 2     | -0.06 | -0.05 | -0.01 | 0.01 | -0.01 | -1.17 | -0.98 | -0.19 | 0.17 | -0.16 |
# | 3     | 0.03 | -0.00 | -0.09 | 0.00 | -0.02 | 0.49 | -0.05 | -1.27 | 0.04 | -0.21 |
# | 4     | -0.10 | -0.19 | -0.17 | 0.08 | -0.09 | -2.10 | -2.41 | -2.31 | 0.98 | -1.15 |
# | Big   | 0.10 | -0.13 | 0.06 | -0.22 | -0.05 | 2.14 | -2.15 | -0.74 | -2.52 | -0.67 |
#
#
# **h and t(h)**
#
# |       | Low h | 2 h | 3 h | 4 h | High h | Low t | 2 t | 3 t | 4 t | High t |
# |-------|--------|--------|--------|--------|----------|--------|--------|--------|--------|----------|
# | Small | 1.05 | 0.93 | 0.91 | 0.89 | 0.97 | 45.86 | 40.94 | 68.62 | 47.20 | 44.65 |
# | 2     | 1.10 | 1.02 | 0.98 | 0.97 | 1.02 | 60.21 | 71.07 | 42.21 | 53.43 | 67.81 |
# | 3     | 1.07 | 1.04 | 1.00 | 1.00 | 1.03 | 61.06 | 53.80 | 36.40 | 52.75 | 42.19 |
# | 4     | 1.05 | 1.10 | 1.07 | 1.02 | 1.15 | 31.69 | 42.41 | 46.33 | 42.45 | 31.21 |
# | Big   | 0.98 | 1.03 | 0.98 | 1.04 | 1.05 | 58.77 | 46.75 | 36.89 | 33.02 | 27.12 |
#
#
# **r and t(r)**
#
# |       | Low r | 2 r | 3 r | 4 r | High r | Low t | 2 t | 3 t | 4 t | High t |
# |-------|--------|--------|--------|--------|----------|---------|---------|---------|---------|-----------|
# | Small | 1.24 | 1.23 | 1.07 | 1.06 | 1.07 | 25.70 | 25.72 | 38.89 | 39.79 | 32.50 |
# | 2     | 0.97 | 0.95 | 0.81 | 0.73 | 0.88 | 29.40 | 28.96 | 28.05 | 34.10 | 34.10 |
# | 3     | 0.69 | 0.64 | 0.49 | 0.45 | 0.58 | 25.73 | 27.29 | 12.99 | 18.32 | 13.43 |
# | 4     | 0.06 | 0.29 | 0.24 | 0.23 | 0.30 | 12.07 | 7.75 | 6.77 | 8.51 | 7.09 |
# | Big   | -0.20 | -0.12 | -0.07 | -0.19 | -0.17 | -9.80 | -4.37 | -5.33 | -6.86 | -2.36 |
#
#
# **c and t(c)**
#
# |       | Low c | 2 c | 3 c | 4 c | High c | Low t | 2 t | 3 t | 4 t | High t |
# |-------|--------|--------|--------|--------|----------|---------|---------|---------|---------|-----------|
# | Small | -0.39 | -0.12 | 0.13 | 0.26 | 0.49 | -7.23 | -2.42 | 5.01 | 7.11 | 14.30 |
# | 2     | -0.47 | -0.03 | 0.29 | 0.40 | 0.64 | -10.19 | -0.87 | 5.56 | 16.64 | 23.88 |
# | 3     | -0.41 | 0.04 | 0.33 | 0.50 | 0.65 | -13.42 | 0.87 | 4.74 | 7.52 | 8.70 |
# | 4     | -0.44 | 0.05 | 0.34 | 0.50 | 0.74 | -13.40 | 0.74 | 4.23 | 7.94 | 10.62 |
# | Big   | -0.31 | -0.12 | -0.03 | 0.72 | 0.98 | -10.89 | -0.37 | -5.87 | 10.90 | 13.84 |

# %%
table9 = plt.imread("table9.png")
plt.imshow(table9)
plt.axis('off')
plt.show()

# %% [markdown]
# **Comment on Tables**: <br><br>
# When comparing our tables to those in the original paper, it is important to note that the authors evaluate model performance primarily through alphas rather than R-squared, and they rely on t-statistics rather than p-values when assessing significance. We follow the same reporting convention in our side-by-side tables above. All coefficients in our regressions are statistically significant, consistent with the patterns emphasized in the original study. Although the authors do not focus on R-squared values, readers who are interested in model fit can find our full set of R-statistics in Section 3(b) and again in the Appendix for reference.

# %% [markdown]
# <h2 style="font-family: Garamond; font-weight: bold; font-size: 18px; margin-bottom: 0.3em;">
# (d) Replication Assessment: Evaluate success of replication:
# </h3>

# %% [markdown]
# Our replication is best characterized as partially successful. Across all size–BM portfolios, the coefficient signs in our regressions match those reported in the original paper, indicating that the core economic relationships emphasized by Fama and French—such as value, size, profitability, and investment exposures—are clearly preserved in our implementation. However, the magnitudes of the coefficients differ substantially from those in Table 9, often falling in the range of 20–60 percent difference depending on the factor and portfolio. Despite these quantitative discrepancies, all of our estimated coefficients are statistically significant, with p-values effectively equal to 0.00, and our t-statistics follow the same directional patterns highlighted by the authors. It is also important to note that, unlike in standard regression settings, R-squared values and the absolute size of t-statistics are not central measures of model quality in the Fama–French framework; the authors instead focus on the alphas, which serve as the primary diagnostic of model performance. Taken together, our results replicate the qualitative structure and factor patterns documented in the paper, but the size of the numerical differences prevents us from claiming a full replication. For this reason, we conclude that our results represent a partial rather than complete replication of the original findings.

# %% [markdown]
# <h2 style="font-family: Garamond; font-weight: bold; font-size: 18px; margin-bottom: 0.3em;">
# (e) Discrepancy Investigation: If results differ, investigate potential reasons:
# </h2>

# %% [markdown]
# Although we use the exact same factor and portfolio data as the original study, the numerical differences between our results and those reported in Table 9 can be traced to two important methodological details. First, the published table is based on HMLO, an orthogonalized version of the HML factor, while our analysis necessarily uses HML, which is the version available in the public dataset. Because orthogonalization changes the correlation structure among the factors, substituting HML for HMLO affects not only the value-loading itself but also the estimated coefficients on the remaining factors. Second, the original paper does not fully specify certain model-estimation details, such as the exact form of the covariance matrix used for inference or whether any adjustments for autocorrelation are applied to the standard errors. In our implementation, we use HAC (Newey–West) standard errors, whereas the paper’s reported t-statistics appear to rely on standard OLS inference. Differences of this kind—while subtle—are well known to shift both coefficient magnitudes and t-statistics even when the underlying data are identical. Together, the use of HML instead of HMLO and the ambiguity surrounding the original estimation details provide a clear explanation for the numerical discrepancies between our estimates and the published results.

# %% [markdown]
# <h1 style="font-family: Garamond; font-weight: bold; font-size: 20px; margin-bottom: 0.3em;">
# 4. Critical Evaluation and Discussion
# </h1>

# %% [markdown]
# <h2 style="font-family: Garamond; font-weight: bold; font-size: 18px; margin-bottom: 0.3em;">
# (a) Agreement/Disagreement with Findings:
# </h2>
#
# <h3 style="font-family: Garamond; font-weight: bold; font-size: 18px; margin-bottom: 0.3em;">
# Agreement on Model Improvement:
# </h3>
# Our results support the authors' conclusion that the Five-Factor model outperforms the Three-Factor model. In the original paper, Fama and French identify the "microcap extreme growth" portfolio as a major failure of the three-factor model. In our replication of the Three-Factor model on the 25 Size-B/M portfolios, the "Small Low B/M" portfolio produced a  negative intercept (α) of -0.742% per month with a t-statistic of -4.78. When we ran the Five-Factor model on the same data, this intercept shrank to -0.276% (t-statistic -3.25). This confirms the authors' finding that adding Profitability (RMW) and Investment (CMA) helps explain—though does not fully eliminate—the pricing errors of small growth stocks.
#
#
# Though our replication supports the authors’ main conclusions, our numerical estimates do not match theirs exactly. The key economic patterns emphasized in the paper—such as strong size, value, profitability, and investment effects, as well as the characteristic loading patterns across portfolios—are clearly present in our results. For example, small firms consistently exhibit higher SMB exposure, high-B/M portfolios load strongly on HML, and firms with robust profitability or conservative investment policies show the expected positive RMW and CMA loadings. These qualitative relationships align closely with the original study. However, the exact regression coefficients and
# t-statistics differ from the published tables, which we attribute to differences in the scale of our recplication relative to the original paper's, rather than inconsistencies in the model itself. As a result, we do not question the authors’ conclusions; instead, our evidence suggests that the five-factor model behaves consistently across datasets, even though numerical estimates vary.
#
# <h3 style="font-family: Garamond; font-weight: bold; font-size: 18px; margin-bottom: 0.3em;">
# Confirmation of "Redundancy":
# </h3>
# We agree with the finding that HML is largely redundant in the presence of RMW and CMA. The authors state that "the average HML return is captured by the exposures of HML to other factors". Our replication provides the statistical mechanism for this: we found a correlation of 0.70 between HML and CMA. Furthermore, in our sample statistics, CMA had a higher t-statistic (4.01) than HML (3.38), suggesting that the investment factor is a more robust driver of returns than the value factor in this sample period.
#
# <h3 style="font-family: Garamond; font-weight: bold; font-size: 18px; margin-bottom: 0.3em;">
# Agreement on Rejection (With Discrepency in GRS):
# </h3>
# We agree with the authors that the model is statistically incomplete, but while we agree the model is imperfect, we question the uniformity of its failure. The authors state the GRS test "easily rejects" the model. However, our replication reveals a massive disparity in how strongly it is rejected. For the 25 Size-B/M portfolios, we calculated a GRS statistic of 63.20 (p≈0). In contrast, for the 25 Size-OP portfolios, the GRS statistic was drastically lower at 1.89 (p=0.005). This suggests that the model's failure is not general, but is specifically acute when assets are sorted by Book-to-Market ratios, a nuance that perhaps warrants more emphasis than a blanket rejection.
#
# <h3 style="font-family: Garamond; font-weight: bold; font-size: 18px; margin-bottom: 0.3em;">
# Confirmation of Correlations:
# </h3>
# We agree with the structural relationships between factors. We replicated the correlation matrix exactly, finding a correlation of 0.70 between HML and CMA and -0.34 between SMB and RMW. This supports the economic logic that value firms invest conservatively, and small firms tend to be less profitable.

# %% [markdown]
# <h2 style="font-family: Garamond; font-weight: bold; font-size: 18px; margin-bottom: 0.3em;">
# (b) Economic Interpretation:
# </h2>
#
# <h3 style="font-family: Garamond; font-weight: bold; font-size: 18px; margin-bottom: 0.3em;">
# Magnitudes and Valuation Theory:
# </h3>
# The magnitudes of the premiums we estimated make economic sense under the Dividend Discount Model ($M_t=∑E(Y−dB)/(1+r)$). We found a mean monthly premium of 0.26% for RMW and 0.33% for CMA. Economically, this implies that investors require a higher return (discount rate $r$) to hold firms that have high expected earnings ($Y$) or low expected asset growth ($dB$), holding market value ($M$) constant. The positive coefficients on RMW for high-profitability portfolios in our regressions (e.g., 1.07 for Small HiOP)  confirm that the market rationally prices profitability as a risk factor.
#
# <h3 style="font-family: Garamond; font-weight: bold; font-size: 18px; margin-bottom: 0.3em;">
# Policy Implications:
# </h3>
# The evidence supports an investment policy that favors "Quality" (Profitability/Investment) over traditional "Value." In our regression results, the HML factor had a lower mean return (0.38%) compared to the combined effect of RMW and CMA. Additionally, the HML factor loadings were often subsumed by CMA loadings in the regressions for high B/M portfolios. For asset managers, this implies that "Value" strategies might just be noisy proxies for "Conservative Investment" strategies. Shifting policy to target CMA directly could provide similar returns with potentially less volatility (CMA Std Dev 2.00 vs HML Std Dev 2.79)
#
# <h3 style="font-family: Garamond; font-weight: bold; font-size: 18px; margin-bottom: 0.3em;">
# Limitations for External Validity:
# </h3>
# A major limitation is the sample period cutoff. Our replication strictly followed the authors' cutoff of December 2013. Economic conditions have changed significantly since 2013 (e.g., near-zero interest rates, the rise of intangible assets). The validity of these factor premiums in the post-2013 economy remains an open question in this specific analysis. The post-2013 economy has been characterized by the dominance of large-cap technology firms (high profitability, high investment). The model's "lethal" failure to price small, high investment firms (which we confirmed with a -0.36% alpha for Small HiInv) might be exacerbated in a modern economy driven by speculative tech growth, limiting the model's validity for current portfolios.

# %% [markdown]
# <h2 style="font-family: Garamond; font-weight: bold; font-size: 18px; margin-bottom: 0.3em;">
# (c) Suggestions for Improvement:
# </h2>
#
# <h3 style="font-family: Garamond; font-weight: bold; font-size: 18px; margin-bottom: 0.3em;">
# Investigation of the GRS Discrepancy:
# </h3>
# A robust check should investigate why the GRS statistic for the Size-B/M portfolios (63.20) is drastically higher than for the Size-Inv portfolios (3.52) or Size-OP portfolios (1.89). This huge disparity suggests that the standard "Size-B/M" sort creates specific linear combinations of assets that the Five-Factor model is particularly bad at pricing, which warrants deeper investigation than just reporting the rejection.
#
# The authors identify small, low-profitability, high-investment stocks as the main problem. To strengthen the paper, we suggest a "trimmed" robustness check. If we exclude the bottom decile of "microcap growth" stocks (which are often illiquid and hard to short), does the model pass the GRS test? Our analysis showed the Small Low B/M alpha was the largest negative outlier (-0.28%). Removing these hard-to-trade assets might reveal that the model works perfectly well for the investable universe.
#
# <h3 style="font-family: Garamond; font-weight: bold; font-size: 18px; margin-bottom: 0.3em;">
# Transaction Cost Analysis:
# </h3>
# The paper assumes frictionless trading. However, the SMB factor (which we found has a mean return of 0.28%) relies on long positions in small-cap stocks. A robustness check should calculate factor returns net of bid-ask spreads. If the "Size" premium disappears after transaction costs, the five-factor model might be overfitting to liquidity premiums rather than fundamental economic risk.
#
# <h3 style="font-family: Garamond; font-weight: bold; font-size: 18px; margin-bottom: 0.3em;">
# Alternative Factor Construction:
# </h3>
# The authors use 2×3 sorts to build factors. We suggest testing if factors built from separate univariate sorts perform better. The high correlation we found between HML and CMA (0.70)  suggests that the sorting methodology itself might be inducing multicollinearity. Constructing orthogonal factors could help isolate the true marginal contribution of Investment versus Value.

# %% [markdown]
# <h1 style="font-family: Garamond; font-weight: bold; font-size: 20px; margin-bottom: 0.3em;">
# 5. Conclusion and Reflection
# </h1>

# %% [markdown]
# <h2 style="font-family: Garamond; font-weight: bold; font-size: 18px; margin-bottom: 0.3em;">
# (a) Summary:
# </h2>
#
# We successfully replicated the Fama-French (2015) Five-Factor model using monthly data from July 1963 to December 2013 (N=606). Our analysis confirms the authors' descriptive results. For instance, our replication found a mean monthly return for the Market factor ($R_M−R_F$) of 0.50% and Size factor (SMB) of 0.28%, which closely matches the original paper’s reported means of 0.50% and 0.29%. Our regression analysis confirmed that the Five-Factor model reduces the unexplained average returns (alpha) for small growth stocks compared to the Three-Factor model. The intercept (α) for the Small Low B/M portfolio improved from -0.74% (t=−4.78) in the Three-Factor specification to -0.28% (t=−3.25) in the Five-Factor specification. However, GRS tests on six different portfolio sets confirmed that the model is still statistically rejected (p<0.01 in all cases).
#
# Crucially, we replicated the structural relationships between factors that drive the paper's main conclusions. We calculated a correlation of 0.70 between the Value (HML) and Investment (CMA) factors , an exact match to the 0.70 correlation reported by Fama and French. This high correlation statistically supports the paper's finding that HML is "redundant" because its information is subsumed by the investment factor. Furthermore, our regression analysis confirmed that the Five-Factor model significantly reduces pricing errors for small growth stocks.

# %% [markdown]
# <h2 style="font-family: Garamond; font-weight: bold; font-size: 18px; margin-bottom: 0.3em;">
# (b) Overall Assessment:
# </h2>
#
# This paper represents a significant theoretical advancement in asset pricing. Unlike the Three-Factor model, which was largely empirically motivated, the Five-Factor model is rigorously grounded in the Dividend Discount Model. The paper successfully bridges the gap between empirical anomalies and valuation theory. By demonstrating that HML is largely redundant due to its correlation with CMA, the authors provide a more parsimonious view of market risks. However, the persistent negative alpha for small, high-investment, low-profitability firms (the "lethal" portfolio) remains a significant unresolved issue, suggesting the model is still missing a factor related to speculative growth.
#
# As the authors state, the valuation equation implies that "higher expected earnings imply a higher expected return" and "higher expected growth in book equity investment implies a lower expected return".
#
# Our replication confirms that this theoretical insight holds empirically: we found robust positive premiums for Profitability (RMW, mean 0.26%) and Investment (CMA, mean 0.33%). However, we assess the model as "incomplete" based on our GRS test results. We calculated a GRS statistic of 63.20 (p≈0) for the 25 Size-B/M portfolios , confirming the authors' admission that the GRS test "easily rejects" the model. Specifically, our finding of a persistent -0.36% monthly alpha for Small High-Investment stocks validates the authors' conclusion that the model suffers from a "lethal" inability to price small firms that invest aggressively despite low profitability.

# %% [markdown]
# <h2 style="font-family: Garamond; font-weight: bold; font-size: 18px; margin-bottom: 0.3em;">
# (c) Learning Reflection:
# </h2>
#
# This replication process provided a practical lesson in the sensitivity of econometric research to data vintage. Although we restricted our sample to the exact 606 months used by the authors, we observed slight discrepancies in volatility metrics—for example, our sample's HML standard deviation was 2.79% compared to the paper's 2.88%. This taught us that financial databases like CRSP and Compustat are not static; historical data is often "restated" or corrected years later.
#
# Additionally, implementing the GRS test deepened our understanding of multivariate testing. We learned that the test's power depends heavily on the precision of the residual covariance matrix (Σ). The massive disparity we found between the GRS statistic for Size-B/M portfolios (63.20) and Size-OP portfolios (1.89)  highlights how sensitive asset pricing models are to the specific characteristics used to sort test assets.

# %% [markdown]
# <h2 style="font-family: Garamond; font-weight: bold; font-size: 18px; margin-bottom: 0.3em;">
# (d) Transparency in Research:
# </h2>
#
# This project highlighted how critical data transparency is. This was seen as we could download the exact csv files for factors and portfolios and match the authors' exact sample count of 606 months, we could distinguish between "failed replication" and "statistical noise." Without publicly available data libraries like Ken French’s, validating complex multivariate models like this would be impossible, leaving the field reliant on trust rather than verification.

# %% [markdown]
# ## Appendix

# %% [markdown]
# ### Section 3

# %% [markdown]
# **Combining Sets and Forming Regression**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
import statsmodels.formula.api as smf
from scipy import stats

factors = pd.read_csv('data/five_factor_model/factors/5f_data.csv', skiprows=4)
factors = factors[pd.to_numeric(factors['Unnamed: 0'], errors='coerce').notna()]
factors = factors.rename(columns={'Unnamed: 0': 'date', 'Mkt-RF': 'MKTRF'})
factors = factors[['date', 'MKTRF', 'SMB', 'HML', 'RMW', 'CMA', 'RF']]
factors.iloc[:, 1:] = factors.iloc[:, 1:].apply(pd.to_numeric, errors='coerce')

portSBM = pd.read_csv('data/five_factor_model/portfolios/25_Portfolios_5x5_on_size_BM.csv', skiprows=15)
portSBM = portSBM.rename(columns={'Unnamed: 0': 'date'})
portSBM = portSBM[pd.to_numeric(portSBM['date'], errors='coerce').notna()]
portSBM = portSBM[:-1]

portSBM.iloc[:, 1:] = portSBM.iloc[:, 1:].apply(pd.to_numeric, errors='coerce')

factors = factors.drop_duplicates(subset='date')
portSBM = portSBM.drop_duplicates(subset='date')

dataSBM = pd.merge(portSBM, factors, on='date', how='inner')
dataSBM['date']
cutoff_row = dataSBM.index[dataSBM['date'] > '201312'][0]
dataSBM = dataSBM.iloc[:cutoff_row]
dataSBM
# Out:
#        date SMALL LoBM ME1 BM2 ME1 BM3 ME1 BM4 SMALL HiBM ME2 BM1 ME2 BM2  \
# 0    196307     1.1287 -0.3632  0.7223 -0.0413    -1.2447 -1.8076  0.1929
# 1    196308     4.2396   1.373  1.4917  2.5068     4.6644  5.5703   4.522
# 2    196309    -1.7343  0.6204 -1.0007 -1.5215    -0.3584 -4.0525 -1.5072
# 3    196310     0.3778 -0.7329  1.3066  0.1904     2.3711  1.1926  4.2411
# 4    196311    -3.3319 -3.8436 -1.7893 -1.0535    -1.1077 -4.2596 -1.7484
# ..      ...        ...     ...     ...     ...        ...     ...     ...
# 601  201308    -2.3217  -2.536 -2.3048 -3.7353    -3.1512 -0.5681 -0.6886
# 602  201309     7.2942  7.5884  7.1963  6.9327     5.8445  6.8252  6.1363
# 603  201310     -0.739  0.7764  2.1975  4.0429       2.87  0.6633  1.5231
# 604  201311     7.7434  5.3439  5.7074  7.1859     4.9367  6.4781  3.6126
# 605  201312     1.6088  3.6044   2.509  1.2559      1.501  2.8395  0.3287
#
#     ME2 BM3 ME2 BM4  ... ME5 BM2 ME5 BM3 ME5 BM4 BIG HiBM MKTRF   SMB   HML  \
# ...

# %%
dataSBM.columns = dataSBM.columns.str.strip()

factor_cols = ['MKTRF', 'SMB', 'HML', 'RMW', 'CMA', 'RF']

dataSBM[factor_cols] = dataSBM[factor_cols].apply(pd.to_numeric, errors='coerce')
X = dataSBM[['MKTRF', 'SMB', 'HML', 'RMW', 'CMA']]
X = sm.add_constant(X)

portfolio_cols = [c for c in dataSBM.columns if c not in factor_cols + ['date']]

results = []

rf = dataSBM['RF']

for port_name in portfolio_cols:
    y = pd.to_numeric(dataSBM[port_name], errors='coerce') - rf

    reg = sm.OLS(y, X, missing='drop').fit(
        cov_type='HAC', cov_kwds={'maxlags': 12}
    )

    results.append({
        'Portfolio': port_name,
        'Alpha': reg.params['const'],
        't(Alpha)': reg.tvalues['const'],
        'b_MKT': reg.params['MKTRF'],
        't(MKT)': reg.tvalues['MKTRF'],
        'b_SMB': reg.params['SMB'],
        't(SMB)': reg.tvalues['SMB'],
        'b_HML': reg.params['HML'],
        't(HML)': reg.tvalues['HML'],
        'b_RMW': reg.params['RMW'],
        't(RMW)': reg.tvalues['RMW'],
        'b_CMA': reg.params['CMA'],
        't(CMA)': reg.tvalues['CMA'],
        'R2': reg.rsquared
    })

resultsSBM = pd.DataFrame(results).set_index('Portfolio')
resultsSBM
# Out:
#                Alpha  t(Alpha)     b_MKT     t(MKT)     b_SMB     t(SMB)  \
# Portfolio
# SMALL LoBM -0.276061 -3.253392  1.052896  45.860957  1.244305  25.704363
# ME1 BM2     0.153988  1.559768  0.929513  40.937171  1.231316  25.722394
# ME1 BM3    -0.020663 -0.375115  0.937119  68.617076  1.073297  38.888013
# ME1 BM4     0.179040  2.623272  0.887755  47.196876  1.062326  39.793398
# SMALL HiBM  0.103783  1.596958  0.970478  44.652659  1.070861  32.499493
# ME2 BM1    -0.069492 -1.165435  1.096112  60.205065  0.972321  29.939089
# ME2 BM2    -0.049703 -0.979706  1.021679  71.017489  0.949824  28.959790
# ME2 BM3    -0.014350 -0.190036  0.979892  42.213016  0.813365  28.046249
# ME2 BM4     0.008849  0.173090  0.968575  63.542817  0.734015  33.341206
# ME2 BM5    -0.009350 -0.158682  1.076203  81.190348  0.880749  34.104028
# ME3 BM1     0.028081  0.487859  1.073643  61.060959  0.693875  25.733591
# ME3 BM2    -0.003465 -0.052053  1.037531  53.804631  0.641697  27.294383
# ...

# %% [markdown]
# **Size and Investment**

# %%
factors = pd.read_csv('data/five_factor_model/factors/5f_data.csv', skiprows=4)
factors = factors[pd.to_numeric(factors['Unnamed: 0'], errors='coerce').notna()]
factors = factors.rename(columns={'Unnamed: 0': 'date', 'Mkt-RF': 'MKTRF'})
factors = factors[['date', 'MKTRF', 'SMB', 'HML', 'RMW', 'CMA', 'RF']]
factors.iloc[:, 1:] = factors.iloc[:, 1:].apply(pd.to_numeric, errors='coerce')


portSIN = pd.read_csv(
    'data/five_factor_model/portfolios/25_Portfolios_ME_INV_5x5.csv',
    skiprows=16         
)
portSIN = portSIN.rename(columns={'Unnamed: 0': 'date'})
portSIN.head()
portSIN = portSIN[:-1]
portSIN
portSIN = portSIN[pd.to_numeric(portSIN['date'], errors='coerce').notna()]
portSIN.iloc[:, 1:] = portSIN.iloc[:, 1:].apply(pd.to_numeric, errors='coerce')
factors = factors.drop_duplicates(subset='date')
portSIN = portSIN.drop_duplicates(subset='date')

dataSIN = pd.merge(portSIN, factors, on='date', how='inner')
cutoff_row = dataSIN.index[dataSIN['date'] > '201312'][0]
dataSIN = dataSIN.iloc[:cutoff_row]
dataSIN
# Out:
#        date SMALL LoINV ME1 INV2 ME1 INV3 ME1 INV4 SMALL HiINV ME2 INV1  \
# 0    196307      0.2217  -1.9977  -0.0859   0.0899      0.4734  -1.5411
# 1    196308      4.5368   1.9844   2.3097   2.2577      2.9373   5.8204
# 2    196309     -0.8673  -0.4042  -1.7032   0.4938     -1.7319   0.0875
# 3    196310       0.951   -0.837   0.2494   2.3211     -1.6296   4.2487
# 4    196311     -2.8287   2.1428  -3.6466  -2.8587     -2.9758   0.0434
# ..      ...         ...      ...      ...      ...         ...      ...
# 601  201308     -3.1578  -3.5358   -3.414  -4.3804     -0.8777  -3.2831
# 602  201309      7.1378   5.7873   6.5806   6.1325      8.1105   6.2765
# 603  201310      1.7927    2.632   3.0992   3.1234     -0.3774   1.4572
# 604  201311      7.1739   5.1384   7.4838   4.2343      5.3932   2.8896
# 605  201312      2.3599   1.2076   1.1724   1.5342      3.0723   3.1835
#
#     ME2 INV2 ME2 INV3 ME2 INV4  ... ME5 INV2 ME5 INV3 ME5 INV4 BIG HiINV  \
# ...

# %%
dataSIN.columns = dataSIN.columns.str.strip()

factor_cols = ['MKTRF', 'SMB', 'HML', 'RMW', 'CMA', 'RF']

dataSIN[factor_cols] = dataSIN[factor_cols].apply(pd.to_numeric, errors='coerce')

X = dataSIN[['MKTRF', 'SMB', 'HML', 'RMW', 'CMA']]
X = sm.add_constant(X)   

portfolio_cols = [c for c in dataSIN.columns if c not in factor_cols + ['date']]

results = []

rf = dataSIN['RF']

for port_name in portfolio_cols:
    y = pd.to_numeric(dataSIN[port_name], errors='coerce') - rf

    reg = sm.OLS(y, X, missing='drop').fit(
        cov_type='HAC', cov_kwds={'maxlags': 12}
    )

    results.append({
        'Portfolio': port_name,
        'Alpha': reg.params['const'],
        't(Alpha)': reg.tvalues['const'],
        'b_MKT': reg.params['MKTRF'],
        't(MKT)': reg.tvalues['MKTRF'],
        'b_SMB': reg.params['SMB'],
        't(SMB)': reg.tvalues['SMB'],
        'b_HML': reg.params['HML'],
        't(HML)': reg.tvalues['HML'],
        'b_RMW': reg.params['RMW'],
        't(RMW)': reg.tvalues['RMW'],
        'b_CMA': reg.params['CMA'],
        't(CMA)': reg.tvalues['CMA'],
        'R2': reg.rsquared
    })

resultsSIN = pd.DataFrame(results).set_index('Portfolio')
resultsSIN
# Out:
#                 Alpha  t(Alpha)     b_MKT     t(MKT)     b_SMB     t(SMB)  \
# Portfolio
# SMALL LoINV  0.216827  1.827064  1.000147  40.817426  1.284126  37.321556
# ME1 INV2     0.101680  1.693965  0.906342  59.129786  1.018550  43.495902
# ME1 INV3     0.125712  2.037205  0.908482  46.961675  1.016175  48.520139
# ME1 INV4     0.029408  0.568211  0.937689  54.923667  1.096775  38.591026
# SMALL HiINV -0.355959 -5.612940  1.027585  50.974328  1.209719  30.940625
# ME2 INV1    -0.022780 -0.430271  1.108057  65.350472  0.920252  35.858796
# ME2 INV2     0.000760  0.012718  0.977775  58.269830  0.752254  21.576017
# ME2 INV3     0.070944  1.514223  0.925180  65.757770  0.829979  29.002833
# ME2 INV4     0.020371  0.406280  1.017160  67.579775  0.857233  36.352829
# ME2 INV5    -0.120621 -2.102966  1.103496  64.254756  0.961629  36.505639
# ME3 INV1     0.034789  0.438996  1.086855  36.685656  0.623084  16.242062
# ...

# %% [markdown]
# **Size and Operating Profit**

# %%
factors = pd.read_csv('data/five_factor_model/factors/5f_data.csv', skiprows=4)
factors = factors[pd.to_numeric(factors['Unnamed: 0'], errors='coerce').notna()]
factors = factors.rename(columns={'Unnamed: 0': 'date', 'Mkt-RF': 'MKTRF'})
factors = factors[['date', 'MKTRF', 'SMB', 'HML', 'RMW', 'CMA', 'RF']]
factors.iloc[:, 1:] = factors.iloc[:, 1:].apply(pd.to_numeric, errors='coerce')

port25SOP = pd.read_csv('data/five_factor_model/portfolios/25_Portfolios_ME_OP_5x5.csv', skiprows=22)
port25SOP = port25SOP.rename(columns={'Unnamed: 0': 'date'})
port25SOP = port25SOP[pd.to_numeric(port25SOP['date'], errors='coerce').notna()]
port25SOP = port25SOP[:-1]
port25SOP.iloc[:, 1:] = port25SOP.iloc[:, 1:].apply(pd.to_numeric, errors='coerce')
factors = factors.drop_duplicates(subset='date')
port25SOP = port25SOP.drop_duplicates(subset='date')

dataSOP = pd.merge(port25SOP, factors, on='date', how='inner')
cutoff_row = dataSOP.index[dataSOP['date'] > '201312'][0]
dataSOP = dataSOP.iloc[:cutoff_row]
dataSOP
# Out:
#        date SMALL LoOP ME1 OP2 ME1 OP3 ME1 OP4 SMALL HiOP ME2 OP1 ME2 OP2  \
# 0    196307    -0.6108   1.273   2.529 -0.5216    -1.0972  -1.175 -1.9451
# 1    196308     2.2692  4.0724  2.8528  2.0117     4.2513  6.6139  6.0332
# 2    196309    -1.2115  -0.876 -2.3407  7.4614    -1.4111 -1.9101 -1.8399
# 3    196310     0.3526  -0.865  0.8505  1.3877     0.3652  3.5288  3.2906
# 4    196311    -2.1603 -1.4852  -2.855 -3.4152    -2.9596 -1.2879 -0.1063
# ..      ...        ...     ...     ...     ...        ...     ...     ...
# 601  201308    -2.7659 -2.8383 -2.9678  -1.537    -4.8959 -2.6271 -3.2617
# 602  201309       7.68  6.5988  4.1738  5.5973     6.9464  6.1359  5.9733
# 603  201310     0.2223  3.1202  3.8849  4.7615     3.2563 -0.5123  2.0712
# 604  201311     6.4302  5.9471  5.2543   7.805     5.1449  3.1331  5.4113
# 605  201312     2.9081  1.0218   0.994  0.4845     2.1586  2.7372  1.3683
#
#     ME2 OP3 ME2 OP4  ... ME5 OP2 ME5 OP3 ME5 OP4 BIG HiOP MKTRF   SMB   HML  \
# ...

# %%
dataSIN.columns = dataSIN.columns.str.strip()

factor_cols = ['MKTRF', 'SMB', 'HML', 'RMW', 'CMA', 'RF']

dataSOP[factor_cols] = dataSOP[factor_cols].apply(pd.to_numeric, errors='coerce')

X = dataSOP[['MKTRF', 'SMB', 'HML', 'RMW', 'CMA']]
X = sm.add_constant(X)  

portfolio_cols = [c for c in dataSOP.columns if c not in factor_cols + ['date']]

results = []

rf = dataSOP['RF']

for port_name in portfolio_cols:
    y = pd.to_numeric(dataSOP[port_name], errors='coerce') - rf

    reg = sm.OLS(y, X, missing='drop').fit(
        cov_type='HAC', cov_kwds={'maxlags': 12}
    )

    results.append({
        'Portfolio': port_name,
        'Alpha': reg.params['const'],
        't(Alpha)': reg.tvalues['const'],
        'b_MKT': reg.params['MKTRF'],
        't(MKT)': reg.tvalues['MKTRF'],
        'b_SMB': reg.params['SMB'],
        't(SMB)': reg.tvalues['SMB'],
        'b_HML': reg.params['HML'],
        't(HML)': reg.tvalues['HML'],
        'b_RMW': reg.params['RMW'],
        't(RMW)': reg.tvalues['RMW'],
        'b_CMA': reg.params['CMA'],
        't(CMA)': reg.tvalues['CMA'],
        'R2': reg.rsquared
    })

resultsSOP = pd.DataFrame(results).set_index('Portfolio')
resultsSOP.to_csv("resultsSOP.csv", index=False)

resultsSOP
# Out:
#                Alpha  t(Alpha)     b_MKT     t(MKT)     b_SMB     t(SMB)  \
# Portfolio
# SMALL LoOP -0.098926 -1.060176  0.975273  47.048226  1.253892  33.815591
# ME1 OP2     0.068813  1.071959  0.922041  50.271091  1.082414  30.422516
# ME1 OP3    -0.094491 -1.392850  0.951584  52.722571  0.984185  26.024534
# ME1 OP4    -0.034599 -0.447524  0.970086  45.149171  1.033043  25.995907
# SMALL HiOP -0.133532 -1.833093  1.092702  49.407275  1.156030  24.613349
# ME2 OP1    -0.029796 -0.430623  1.102230  57.440533  0.923687  34.934422
# ME2 OP2    -0.094922 -1.503040  1.029425  48.909583  0.833585  22.964416
# ME2 OP3    -0.045180 -0.843776  0.954892  74.791726  0.798411  31.778442
# ME2 OP4    -0.098936 -1.436976  0.997447  55.345145  0.864569  31.837624
# ME2 OP5     0.001869  0.025662  1.107903  44.940708  0.958553  22.025463
# ME3 OP1     0.063329  0.823607  1.074237  53.132529  0.582338  17.851912
# ME3 OP2    -0.028079 -0.398358  0.990665  48.176206  0.557609  19.735771
# ...

# %% [markdown]
# **B/M and Investment**

# %%
factors = pd.read_csv('data/five_factor_model/factors/5f_data.csv', skiprows=4)
factors = factors[pd.to_numeric(factors['Unnamed: 0'], errors='coerce').notna()]
factors = factors.rename(columns={'Unnamed: 0': 'date', 'Mkt-RF': 'MKTRF'})
factors = factors[['date', 'MKTRF', 'SMB', 'HML', 'RMW', 'CMA', 'RF']]
factors.iloc[:, 1:] = factors.iloc[:, 1:].apply(pd.to_numeric, errors='coerce')

portBMIN = pd.read_csv('data/five_factor_model/portfolios/32_Portfolios_ME_BEME_INV_2x4x4.csv', skiprows=16)
portBMIN = portBMIN.rename(columns={'Unnamed: 0': 'date'})
portBMIN = portBMIN[pd.to_numeric(portBMIN['date'], errors='coerce').notna()]
portBMIN = portBMIN[:-1]
portBMIN.head()
portBMIN.iloc[:, 1:] = portBMIN.iloc[:, 1:].apply(pd.to_numeric, errors='coerce')
factors = factors.drop_duplicates(subset='date')
portBMIN = portBMIN.drop_duplicates(subset='date')

dataBMIN = pd.merge(portBMIN, factors, on='date', how='inner')
cutoff_row = dataBMIN.index[dataBMIN['date'] > '201312'][0]
dataBMIN = dataBMIN.iloc[:cutoff_row]
dataBMIN
# Out:
#        date SMALL LoBM LoINV ME1 BM1 INV2 ME1 BM1 INV3 SMALL LoBM HiINV  \
# 0    196307            2.287      -2.2391      -0.1713          -1.0548
# 1    196308           5.0568       1.9263       4.0515           5.8317
# 2    196309          -3.7009       0.5667       -2.078          -2.5026
# 3    196310           0.0727       0.9517       3.1849           0.1872
# 4    196311          -2.0991       -2.469      -2.7259          -2.9307
# ..      ...              ...          ...          ...              ...
# 601  201308          -3.5783      -2.2329      -2.4635           0.8804
# 602  201309           4.7731       6.0205       4.9644           7.6435
# 603  201310           1.4271       1.7605       3.4091            0.415
# 604  201311           5.6378       5.6085       3.6017           5.1732
# 605  201312           3.3882       1.8438       0.6744           1.9134
#
#     ME1 BM2 INV1 ME1 BM2 INV2 ME1 BM2 INV3 ME1 BM2 INV4 ME1 BM3 INV1  ...  \
# ...

# %%
dataBMIN.columns = dataBMIN.columns.str.strip()

factor_cols = ['MKTRF', 'SMB', 'HML', 'RMW', 'CMA', 'RF']

dataBMIN[factor_cols] = dataBMIN[factor_cols].apply(pd.to_numeric, errors='coerce')
X = dataBMIN[['MKTRF', 'SMB', 'HML', 'RMW', 'CMA']]
X = sm.add_constant(X)

portfolio_cols = [c for c in dataBMIN.columns if c not in factor_cols + ['date']]

results = []

rf = dataBMIN['RF']

for port_name in portfolio_cols:
    y = pd.to_numeric(dataBMIN[port_name], errors='coerce') - rf

    reg = sm.OLS(y, X, missing='drop').fit(
        cov_type='HAC', cov_kwds={'maxlags': 12}
    )

    results.append({
        'Portfolio': port_name,
        'Alpha': reg.params['const'],
        't(Alpha)': reg.tvalues['const'],
        'b_MKT': reg.params['MKTRF'],
        't(MKT)': reg.tvalues['MKTRF'],
        'b_SMB': reg.params['SMB'],
        't(SMB)': reg.tvalues['SMB'],
        'b_HML': reg.params['HML'],
        't(HML)': reg.tvalues['HML'],
        'b_RMW': reg.params['RMW'],
        't(RMW)': reg.tvalues['RMW'],
        'b_CMA': reg.params['CMA'],
        't(CMA)': reg.tvalues['CMA'],
        'R2': reg.rsquared
    })

resultsBMIN = pd.DataFrame(results).set_index('Portfolio')
resultsBMIN
# Out:
#                      Alpha  t(Alpha)     b_MKT     t(MKT)     b_SMB  \
# Portfolio
# SMALL LoBM LoINV -0.013720 -0.145985  1.070870  57.142979  1.142410
# ME1 BM1 INV2      0.074432  1.030510  0.992086  43.282581  0.917188
# ME1 BM1 INV3      0.120806  2.272382  0.974762  70.970444  0.913424
# SMALL LoBM HiINV -0.180470 -3.542489  1.092551  65.747578  1.014468
# ME1 BM2 INV1      0.046799  0.675385  1.053913  33.775275  0.961273
# ME1 BM2 INV2      0.022265  0.398130  0.938309  53.390121  0.730715
# ME1 BM2 INV3     -0.032886 -0.540514  0.946201  49.583112  0.817473
# ME1 BM2 INV4     -0.053919 -0.846386  1.026660  54.367891  0.932957
# ME1 BM3 INV1      0.123246  1.417575  1.031961  43.083592  0.984273
# ME1 BM3 INV2     -0.051245 -1.045256  0.934203  61.106598  0.748499
# ME1 BM3 INV3      0.145705  2.786901  0.928829  57.051466  0.731155
# ME1 BM3 INV4     -0.082118 -1.082335  1.028372  43.824795  0.882192
# SMALL HiBM LoINV  0.055391  0.602602  1.125375  36.974666  1.008000
# ...

# %% [markdown]
# **B/M Operating Profit**

# %%
factors = pd.read_csv('data/five_factor_model/factors/5f_data.csv', skiprows=4)
factors = factors[pd.to_numeric(factors['Unnamed: 0'], errors='coerce').notna()]
factors = factors.rename(columns={'Unnamed: 0': 'date', 'Mkt-RF': 'MKTRF'})
factors = factors[['date', 'MKTRF', 'SMB', 'HML', 'RMW', 'CMA', 'RF']]
factors.iloc[:, 1:] = factors.iloc[:, 1:].apply(pd.to_numeric, errors='coerce')

portBMOP = pd.read_csv('data/five_factor_model/portfolios/32_Portfolios_ME_BEME_OP_2x4x4.csv', skiprows=23)
portBMOP = portBMOP.rename(columns={'Unnamed: 0': 'date'})
portBMOP = portBMOP[pd.to_numeric(portBMOP['date'], errors='coerce').notna()]
portBMOP = portBMOP[:-1]
portBMOP.head()
portBMOP.iloc[:, 1:] = portBMOP.iloc[:, 1:].apply(pd.to_numeric, errors='coerce')
factors = factors.drop_duplicates(subset='date')
portBMOP = portBMOP.drop_duplicates(subset='date')

dataBMOP = pd.merge(portBMOP, factors, on='date', how='inner')
cutoff_row = dataBMOP.index[dataBMOP['date'] > '201312'][0]
dataBMOP = dataBMOP.iloc[:cutoff_row]
dataBMOP
# Out:
#        date SMALL LoBM LoOP ME1 BM1 OP2 ME1 BM1 OP3 SMALL LoBM HiOP  \
# 0    196307          -0.758     -1.3712     -0.8586         -0.4613
# 1    196308          2.1338      9.7448      2.6713          5.1957
# 2    196309         -1.5143     -2.1044      0.0405         -2.7377
# 3    196310         -2.1998      1.4798       2.148          1.2446
# 4    196311          -5.658      1.0325     -2.4006         -2.6364
# ..      ...             ...         ...         ...             ...
# 601  201308         -1.3204     -0.7074     -2.0222         -1.0024
# 602  201309          5.8897      7.5773      5.1148          6.7629
# 603  201310         -3.6549      1.0061      4.9072          3.6872
# 604  201311          5.2049      2.8923       4.761          5.4742
# 605  201312          2.6737      1.5063      1.1691          1.8904
#
#     ME1 BM2 OP1 ME1 BM2 OP2 ME1 BM2 OP3 ME1 BM2 OP4 ME1 BM3 OP1  ...  \
# 0        3.9062     -0.2508      -0.971      2.3822     -1.3823  ...
# ...

# %%
dataBMOP.columns = dataBMOP.columns.str.strip()

factor_cols = ['MKTRF', 'SMB', 'HML', 'RMW', 'CMA', 'RF']

dataBMOP[factor_cols] = dataBMOP[factor_cols].apply(pd.to_numeric, errors='coerce')
X = dataBMOP[['MKTRF', 'SMB', 'HML', 'RMW', 'CMA']]
X = sm.add_constant(X)   

portfolio_cols = [c for c in dataBMOP.columns if c not in factor_cols + ['date']]

results = []

rf = dataBMOP['RF']

for port_name in portfolio_cols:
    y = pd.to_numeric(dataBMOP[port_name], errors='coerce') - rf

    reg = sm.OLS(y, X, missing='drop').fit(
        cov_type='HAC', cov_kwds={'maxlags': 12}
    )

    results.append({
        'Portfolio': port_name,
        'Alpha': reg.params['const'],
        't(Alpha)': reg.tvalues['const'],
        'b_MKT': reg.params['MKTRF'],
        't(MKT)': reg.tvalues['MKTRF'],
        'b_SMB': reg.params['SMB'],
        't(SMB)': reg.tvalues['SMB'],
        'b_HML': reg.params['HML'],
        't(HML)': reg.tvalues['HML'],
        'b_RMW': reg.params['RMW'],
        't(RMW)': reg.tvalues['RMW'],
        'b_CMA': reg.params['CMA'],
        't(CMA)': reg.tvalues['CMA'],
        'R2': reg.rsquared
    })

resultsBMOP = pd.DataFrame(results).set_index('Portfolio')
resultsBMOP
# Out:
#                     Alpha  t(Alpha)     b_MKT     t(MKT)     b_SMB     t(SMB)  \
# Portfolio
# SMALL LoBM LoOP -0.339381 -3.481502  1.063122  39.694115  1.142983  21.613087
# ME1 BM1 OP2     -0.021124 -0.195335  1.090831  30.654177  0.970780  16.173953
# ME1 BM1 OP3     -0.116409 -1.703754  1.034581  50.863216  0.922870  38.707648
# SMALL LoBM HiOP -0.108348 -2.066124  1.089756  52.562716  0.957469  27.965496
# ME1 BM2 OP1      0.035909  0.323000  1.064485  40.361200  1.055083  17.275647
# ME1 BM2 OP2     -0.089288 -1.302731  0.991517  38.936964  0.863347  22.319397
# ME1 BM2 OP3     -0.061178 -1.218335  0.937578  43.883082  0.730999  24.536662
# ME1 BM2 OP4      0.010479  0.139835  1.010567  50.434548  0.867658  25.676803
# ME1 BM3 OP1     -0.048044 -0.624557  1.048415  62.971498  1.043319  32.090104
# ME1 BM3 OP2     -0.081836 -1.259070  0.948567  36.485846  0.717019  24.679254
# ME1 BM3 OP3      0.089517  1.486237  0.914151  52.610286  0.732033  28.136656
# ...

# %% [markdown]
# **Operating Profit and Investment**

# %%
factors = pd.read_csv('data/five_factor_model/factors/5f_data.csv', skiprows=4)
factors = factors[pd.to_numeric(factors['Unnamed: 0'], errors='coerce').notna()]
factors = factors.rename(columns={'Unnamed: 0': 'date', 'Mkt-RF': 'MKTRF'})
factors = factors[['date', 'MKTRF', 'SMB', 'HML', 'RMW', 'CMA', 'RF']]
factors.iloc[:, 1:] = factors.iloc[:, 1:].apply(pd.to_numeric, errors='coerce')

portOPIN = pd.read_csv('data/five_factor_model/portfolios/32_Portfolios_ME_BEME_OP_2x4x4.csv', skiprows=23)
portOPIN = portOPIN.rename(columns={'Unnamed: 0': 'date'})
portOPIN = portOPIN[pd.to_numeric(portOPIN['date'], errors='coerce').notna()]
portOPIN = portOPIN[:-1]
portOPIN.head()
portOPIN.iloc[:, 1:] = portOPIN.iloc[:, 1:].apply(pd.to_numeric, errors='coerce')
factors = factors.drop_duplicates(subset='date')
portOPIN = portOPIN.drop_duplicates(subset='date')

dataOPIN = pd.merge(portOPIN, factors, on='date', how='inner')
cutoff_row = dataOPIN.index[dataOPIN['date'] > '201312'][0]
dataOPIN = dataOPIN.iloc[:cutoff_row]
dataOPIN
# Out:
#        date SMALL LoBM LoOP ME1 BM1 OP2 ME1 BM1 OP3 SMALL LoBM HiOP  \
# 0    196307          -0.758     -1.3712     -0.8586         -0.4613
# 1    196308          2.1338      9.7448      2.6713          5.1957
# 2    196309         -1.5143     -2.1044      0.0405         -2.7377
# 3    196310         -2.1998      1.4798       2.148          1.2446
# 4    196311          -5.658      1.0325     -2.4006         -2.6364
# ..      ...             ...         ...         ...             ...
# 601  201308         -1.3204     -0.7074     -2.0222         -1.0024
# 602  201309          5.8897      7.5773      5.1148          6.7629
# 603  201310         -3.6549      1.0061      4.9072          3.6872
# 604  201311          5.2049      2.8923       4.761          5.4742
# 605  201312          2.6737      1.5063      1.1691          1.8904
#
#     ME1 BM2 OP1 ME1 BM2 OP2 ME1 BM2 OP3 ME1 BM2 OP4 ME1 BM3 OP1  ...  \
# 0        3.9062     -0.2508      -0.971      2.3822     -1.3823  ...
# ...

# %%
dataOPIN.columns = dataOPIN.columns.str.strip()

factor_cols = ['MKTRF', 'SMB', 'HML', 'RMW', 'CMA', 'RF']

dataOPIN[factor_cols] = dataOPIN[factor_cols].apply(pd.to_numeric, errors='coerce')
X = dataOPIN[['MKTRF', 'SMB', 'HML', 'RMW', 'CMA']]
X = sm.add_constant(X)   

portfolio_cols = [c for c in dataOPIN.columns if c not in factor_cols + ['date']]

results = []

rf = dataOPIN['RF']

for port_name in portfolio_cols:
    y = pd.to_numeric(dataOPIN[port_name], errors='coerce') - rf

    reg = sm.OLS(y, X, missing='drop').fit(
        cov_type='HAC', cov_kwds={'maxlags': 12}
    )

    results.append({
        'Portfolio': port_name,
        'Alpha': reg.params['const'],
        't(Alpha)': reg.tvalues['const'],
        'b_MKT': reg.params['MKTRF'],
        't(MKT)': reg.tvalues['MKTRF'],
        'b_SMB': reg.params['SMB'],
        't(SMB)': reg.tvalues['SMB'],
        'b_HML': reg.params['HML'],
        't(HML)': reg.tvalues['HML'],
        'b_RMW': reg.params['RMW'],
        't(RMW)': reg.tvalues['RMW'],
        'b_CMA': reg.params['CMA'],
        't(CMA)': reg.tvalues['CMA'],
        'R2': reg.rsquared
    })

resultsOPIN = pd.DataFrame(results).set_index('Portfolio')
resultsOPIN
# Out:
#                     Alpha  t(Alpha)     b_MKT     t(MKT)     b_SMB     t(SMB)  \
# Portfolio
# SMALL LoBM LoOP -0.339381 -3.481502  1.063122  39.694115  1.142983  21.613087
# ME1 BM1 OP2     -0.021124 -0.195335  1.090831  30.654177  0.970780  16.173953
# ME1 BM1 OP3     -0.116409 -1.703754  1.034581  50.863216  0.922870  38.707648
# SMALL LoBM HiOP -0.108348 -2.066124  1.089756  52.562716  0.957469  27.965496
# ME1 BM2 OP1      0.035909  0.323000  1.064485  40.361200  1.055083  17.275647
# ME1 BM2 OP2     -0.089288 -1.302731  0.991517  38.936964  0.863347  22.319397
# ME1 BM2 OP3     -0.061178 -1.218335  0.937578  43.883082  0.730999  24.536662
# ME1 BM2 OP4      0.010479  0.139835  1.010567  50.434548  0.867658  25.676803
# ME1 BM3 OP1     -0.048044 -0.624557  1.048415  62.971498  1.043319  32.090104
# ME1 BM3 OP2     -0.081836 -1.259070  0.948567  36.485846  0.717019  24.679254
# ME1 BM3 OP3      0.089517  1.486237  0.914151  52.610286  0.732033  28.136656
# ...

# %% [markdown]
# **Three Factor Model with Size and B/M**

# %%
tfactors = pd.read_csv('data/three_factor_model/factors/3f_data.csv', skiprows=4)
tfactors = tfactors[pd.to_numeric(tfactors['Unnamed: 0'], errors='coerce').notna()]
tfactors = tfactors.rename(columns={'Unnamed: 0': 'date', 'Mkt-RF': 'MKTRF'})
tfactors = tfactors[['date', 'MKTRF', 'SMB', 'HML', 'RF']]
tfactors.iloc[:, 1:] = tfactors.iloc[:, 1:].apply(pd.to_numeric, errors='coerce')
portSBM = pd.read_csv('data/five_factor_model/portfolios/25_Portfolios_5x5_on_size_BM.csv', skiprows=15)
portSBM = portSBM.rename(columns={'Unnamed: 0': 'date'})
portSBM = portSBM[pd.to_numeric(portSBM['date'], errors='coerce').notna()]
portSBM = portSBM[:-1]
portSBM.iloc[:, 1:] = portSBM.iloc[:, 1:].apply(pd.to_numeric, errors='coerce')

tfactors = tfactors.drop_duplicates(subset='date')
portSBM = portSBM.drop_duplicates(subset='date')

data3 = pd.merge(portSBM, tfactors, on='date', how='inner')
cutoff_row = data3.index[data3['date'] > '201312'][0]
data3 = data3.iloc[:cutoff_row]
data3
# Out:
#         date SMALL LoBM ME1 BM2 ME1 BM3 ME1 BM4 SMALL HiBM ME2 BM1 ME2 BM2  \
# 0     192607     5.8276 -1.7006  0.5118 -2.1477     1.9583  1.2118  2.4107
# 1     192608    -2.0206 -8.0282  1.3968  2.1483     8.5104   2.362 -0.7525
# 2     192609    -4.8291 -2.6806 -4.3417 -3.2683     0.8586 -2.6849 -0.5252
# 3     192610    -9.3633 -3.5519 -3.5024  3.4413    -2.5452 -2.8014 -4.4191
# 4     192611     5.5888  4.1877  2.4384 -4.4495      0.511  3.1023 -1.7317
# ...      ...        ...     ...     ...     ...        ...     ...     ...
# 1045  201308    -2.3217  -2.536 -2.3048 -3.7353    -3.1512 -0.5681 -0.6886
# 1046  201309     7.2942  7.5884  7.1963  6.9327     5.8445  6.8252  6.1363
# 1047  201310     -0.739  0.7764  2.1975  4.0429       2.87  0.6633  1.5231
# 1048  201311     7.7434  5.3439  5.7074  7.1859     4.9367  6.4781  3.6126
# 1049  201312     1.6088  3.6044   2.509  1.2559      1.501  2.8395  0.3287
#
# ...
